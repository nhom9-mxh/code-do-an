# %%
import pandas as pd
from utils.encode import *
from utils.edge import *

courses = pd.read_csv("/home/ptdat/Desktop/graph/course_labeled.csv")[["id", "course_classification"]]
courses = courses[~courses["id"].isin(["C_608132", "C_676649", "C_676661", "C_676683", "C_676686", "C_676897", "C_676962", "C_676996", "C_677019", "C_680882", "C_680920", "C_681355", "C_681518", "C_681567", "C_681573", "C_681575", "C_681578", "C_681580", "C_681581", "C_681583", "C_681585", "C_681587", "C_681588", "C_681592"])]
courses.head()
# Out:
# If you want to use `XLMRobertaLMHeadModel` as a standalone, add `is_decoder=True.`
#          id course_classification
# 0  C_655852                normal
# 1  C_655850                   bad
# 2  C_654554                normal
# 3  C_654506                   bad
# 4  C_629558                normal

# %%
from pymongo import MongoClient
from pymongo.collection import Collection

client = MongoClient("mongodb://root:example@localhost:27017/")
db = client["database"]

# %%
from itertools import product
import re

def query(course_id: str, db: Collection):
    # Course
    course = db["course"].find_one({"_id": course_id}, projection=["about", "prerequisites", "school_id", "field"])
    # Fields
    fields = course.pop("field")
    # Resources
    resources = list(db["resource"].find({"course_id": course_id}, projection={"title": {"$arrayElemAt": ["$titles", 0]}, "ccid": 1}))
    # School
    schools = list(db["school"].find({}, projection=["name", "about", "motto"]))
    # Teachers
    teacher_ids = [re.search(r"T_\d+$", dict(i)["_id"]).group(0) for i in db["course-teacher"].find({"_id": {"$regex": f"^{course_id}"}})]
    teachers = list(db["teacher"].find({"_id": {"$in": teacher_ids}}, projection=["about", "job_title", "org_name"]))
    # Users
    user_ids = [re.search(r"U_\d+$", dict(i)["_id"]).group(0) for i in db["user_course"].find({"_id": {"$regex": f"^{course_id}"}})]
    users = list(db["user"].find({"_id": {"$in": user_ids}, "gender": {"$in": [0, 1, 2]}}, projection=["school", "gender"]))
    # Comments
    comments = list(db["comment"].find({"course_id": course_id}, projection=["text", "user_id"]))
    # Replies
    comment_ids = [comment["_id"] for comment in comments]
    replies = list(db["reply"].find({"comment_id": {"$in": comment_ids}}, projection=["text", "user_id", "comment_id"]))
    # Exercises
    resource_ids = [resource["_id"] for resource in resources]
    exercises = list(db["problem"].find({"exercise_id": {"$in": resource_ids}}, projection=["title", "content", "typetext", "exercise_id"]))
    # Videos
    ccids = list(set([resource["ccid"] for resource in resources if "ccid" in resource]))
    videos = list(db["video"].find({"_id": {"$in": ccids}}, projection=["name", "text"]))

    return dict(
        course=course,
        fields=fields,
        resources=resources,
        schools=schools,
        teachers=teachers,
        users=users,
        comments=comments,
        replies=replies,
        exercises=exercises,
        videos=videos,
    )

# %%
c_id = courses.loc[52, "id"]
sample = query(course_id=c_id, db=db)
print(c_id)
sample
# Out:
# C_676953
# {'course': {'_id': 'C_676953',
#   'prerequisites': 'C语言',
#   'about': '不仅仅是一门编程语言，汇编语言更是计算机系统软硬件的分界与桥梁，是理解整个计算机系统的有效起点，为学习后续的计算机系统课程打下基础。',
#   'school_id': 'S_1'},
#  'fields': ['计算机科学与技术'],
#  'resources': [{'_id': 'V_71673',
#    'ccid': 'BB2012EAC138EA979C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71674',
#    'ccid': 'DC4227387F8716419C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71675',
#    'ccid': '28B3AA48D6C4DCBA9C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71676',
#    'ccid': '55A4D3424F9E38539C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71677',
#    'ccid': 'B2DF7CB98A899C0E9C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71678',
#    'ccid': 'F1605AD9493E4C669C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71679',
#    'ccid': 'F583D1EE366342779C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71680',
#    'ccid': '93238A9393F49BCB9C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71681',
#    'ccid': 'D91EC6FCA01C69749C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71682',
#    'ccid': '52E38E401BA4E9569C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71683',
#    'ccid': '80C7CC1B874390E59C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71684',
#    'ccid': '77D8C7497773B4879C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71685',
#    'ccid': 'B6875014B3182E179C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'Ex_1067788', 'title': '一、基础知识'},
#   {'_id': 'V_71686',
#    'ccid': '57E6172D63C5793D9C33DC5901307461',
#    'title': '二、X86体系结构初步'},
#   {'_id': 'V_71687',
#    'ccid': 'EABB70C5881F858D9C33DC5901307461',
#    'title': '二、X86体系结构初步'},
#   {'_id': 'V_71688',
#    'ccid': '90E4F174D9933EF49C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71689',
#    'ccid': 'C043E9629D4443BA9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71690',
#    'ccid': 'D96C1DB23620E4339C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71691',
#    'ccid': 'BADA540A29F26F099C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71692',
#    'ccid': 'E0CE3D9E783002799C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71693',
#    'ccid': 'D7E88CCCECF7E44C9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71694',
#    'ccid': '3920E09BED9819859C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71695',
#    'ccid': '99289310CF978D089C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71696',
#    'ccid': '0BB8660EEA39D9129C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71697',
#    'ccid': 'F9053B0221C642FF9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71698',
#    'ccid': '03441403C4335FEB9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71699',
#    'ccid': 'D3097D0490F67F499C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71700',
#    'ccid': 'C2D81CED109272F09C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'Ex_1067790', 'title': '三、C与汇编语言'},
#   {'_id': 'V_71701',
#    'ccid': '729779BA1518AA7D9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71702',
#    'ccid': '00D2103C2C75894E9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71703',
#    'ccid': '8F6540CC45FFBF0B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71704',
#    'ccid': 'B21007DE273239A89C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71705',
#    'ccid': '0D760108788F4D0B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71706',
#    'ccid': '8D6545F9A7A9D5919C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71707',
#    'ccid': 'A182AFE3568886B39C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71708',
#    'ccid': 'B479F55E9C188D189C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71709',
#    'ccid': '8B450E01EC8293AD9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71710',
#    'ccid': 'C08E35A62B23A7439C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71711',
#    'ccid': '84D4F567E5D759039C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71712',
#    'ccid': 'B15B6D5A0E2165409C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71713',
#    'ccid': '57A5EBCF309977BE9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71714',
#    'ccid': '62596848F9D3A6B39C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71715',
#    'ccid': 'CB830E31A15AFB139C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71716',
#    'ccid': '973F618E8955C29D9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71717',
#    'ccid': 'CF58326927DB3EEF9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71718',
#    'ccid': '76AABC8383AA62339C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71719',
#    'ccid': 'B3E85AE92E0C71CE9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71720',
#    'ccid': '036129657D0E150E9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71721',
#    'ccid': '182B2E76A8909EAD9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71722',
#    'ccid': 'E67EDE9FB78918789C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71723',
#    'ccid': '0DA132AD4F7CCBCC9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71724',
#    'ccid': 'E06378F968494BA09C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71725',
#    'ccid': '58989B04461B46A79C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71726',
#    'ccid': 'B23F4692834CC02B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71727',
#    'ccid': 'B59FDC75B1E6B95B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71728',
#    'ccid': 'EC8115B5D889E0009C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71729',
#    'ccid': '273DA4DB2C3561A99C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71730',
#    'ccid': 'BD9BBB84743BEA4D9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71731',
#    'ccid': 'B9383FFAFFF157EE9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71732',
#    'ccid': '3AF8FC65575C7F969C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71733',
#    'ccid': 'F41455BB6060096B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71734',
#    'ccid': '05FC849634F262859C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'Ex_1067791', 'title': '三、C与汇编语言'},
#   {'_id': 'V_71735',
#    'ccid': '1B9C2416C1BCFEFD9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71736',
#    'ccid': '6158DB949599CB659C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71737',
#    'ccid': 'B44888A4147311849C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71738',
#    'ccid': 'BBA18F49B187BBE89C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71739',
#    'ccid': '6D22ECECE415585C9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71740',
#    'ccid': 'D3C8AB3A3CA267B49C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'Ex_1067789', 'title': '三、C与汇编语言'},
#   {'_id': 'V_71741',
#    'ccid': '177A8173AA5561C79C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71742',
#    'ccid': '44F77BFAFBC7020B9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71743',
#    'ccid': '1B037196AE18DCC49C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71744',
#    'ccid': '0134B7CCFACD07B99C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71745',
#    'ccid': 'CEBED48A41E825A39C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'Ex_1067792', 'title': '四、\t汇编编程'},
#   {'_id': 'V_71746',
#    'ccid': '87D28DFBC6EF86E39C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71747',
#    'ccid': 'DB2EA5C5439229189C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71748',
#    'ccid': '399FA6CACF3112D89C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71749',
#    'ccid': '8F5151291F7F1B929C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71750',
#    'ccid': 'BDF912EA03D34EE79C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71751',
#    'ccid': 'E7122C05422418E29C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71752',
#    'ccid': 'E22283391062C5709C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71753',
#    'ccid': '085458758A0BCA499C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71754',
#    'ccid': 'BC13A7926CEB26B59C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71755',
#    'ccid': 'C469D0515A0664049C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71756',
#    'ccid': 'E5048843DB71A22B9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71757',
#    'ccid': 'A695096A4C335A8E9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71758',
#    'ccid': '7D51374FE56E98F59C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71759',
#    'ccid': 'D52F480E6D6F315E9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71760',
#    'ccid': '8C6E52E79815D1FC9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71761',
#    'ccid': 'FC709B4D20772A729C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71762',
#    'ccid': '24C72F80354A78309C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71763',
#    'ccid': '146774C6510F01A59C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71764',
#    'ccid': '5CEC1C1771A253909C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71765',
#    'ccid': 'B90AC00ADDF299229C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71766',
#    'ccid': '361B4E73FD34A45A9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71767',
#    'ccid': 'C576B4EC2FA119C99C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71768',
#    'ccid': 'FFD6B6E681974C739C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71769',
#    'ccid': 'C839096B2353111C9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71770',
#    'ccid': '00848A2EAF9DA5369C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71771',
#    'ccid': 'C81CC752272A1F239C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71772',
#    'ccid': '47D4987072FFF0B39C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71773',
#    'ccid': '03FE2B6C2434EAD79C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71774',
#    'ccid': '5835E41DD9A95BDB9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71775',
#    'ccid': '13DA74E75C6D3BD89C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'Ex_1067793', 'title': '四、\t汇编编程'},
#   {'_id': 'V_71776',
#    'ccid': '184BAA4A1E458C939C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71777',
#    'ccid': 'DE54A38371A2B96F9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71778',
#    'ccid': '3EFC69B9A092065D9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71779',
#    'ccid': '2144AA2746158B6A9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71780',
#    'ccid': 'C652BE13F3F3BD429C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71781',
#    'ccid': 'DEF75F9C28B43BB39C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71782',
#    'ccid': 'B823B3D0DD6C241D9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71783',
#    'ccid': '5DC8A08627BFE82E9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71784',
#    'ccid': '74507233A6717AD39C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71785',
#    'ccid': '0AD3C450811FF20C9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71786',
#    'ccid': '9F2E7CDC7D0FE07C9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71787',
#    'ccid': '12532056530A748C9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71788',
#    'ccid': 'BD9F3AC6A4DC3A559C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71789',
#    'ccid': '3029C26E425E758F9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71790',
#    'ccid': '7A1596ABFE156C449C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71791',
#    'ccid': '1B0AD22BDBB3F8899C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71792',
#    'ccid': 'E6FDB1DDA2388D059C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71793',
#    'ccid': 'BD5EEFD7B79A822E9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71794',
#    'ccid': '0D1E382A10284E259C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71795',
#    'ccid': '32FDF02CC0EDA40E9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'Ex_1067794', 'title': '五、MIPS汇编'},
#   {'_id': 'V_71796',
#    'ccid': '1A9E1A19E35C99B79C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71797',
#    'ccid': '4287F1B28B6D43B29C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71798',
#    'ccid': '7EE263DCBEDBCB5F9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71799',
#    'ccid': 'C12DBE1061E778CF9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71800',
#    'ccid': '990EDBFD0FDE3DE59C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71801',
#    'ccid': '0C6C4855D7EA4AF29C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71802',
#    'ccid': '33BCBF783119219D9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71803',
#    'ccid': 'CEFF530DD75222C69C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71804',
#    'ccid': 'E7840B18BE9CB29B9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71805',
#    'ccid': '90E88265B9CFFD6F9C33DC5901307461',
#    'title': '五、MIPS汇编'}],
#  'schools': [{'_id': 'S_1',
#    'name': '清华大学',
#    'about': '简称“清华”，由中华人民共和国教育部直属，中央直管副部级建制，位列“211工程”、“985工程”、“世界一流大学和一流学科”，入选“基础学科拔尖学生培养试验计划”、“高等学校创新能力提升计划”、“高等学校学科创新引智计划”，为九校联盟、松联盟、中国大学校长联谊会、亚洲大学联盟、环太平洋大学联盟、清华—剑桥—MIT低碳大学联盟成员，被誉为“红色工程师的摇篮”。',
#    'motto': '自强不息,厚德载物'},
#   {'_id': 'S_2',
#    'name': '北京大学',
#    'about': '北京大学（Peking University），简称“北大”，是中华人民共和国教育部直属的全国重点大学，位列“双一流”、“211工程”、“985工程”，入选“学位授权自主审核单位”、“基础学科拔尖学生培养试验计划”、“基础学科招生改革试点”、“高等学校创新能力提升计划”、“高等学校学科创新引智计划”，为九校联盟、松联盟、中国大学校长联谊会、京港大学联盟、亚洲大学联盟、东亚研究型大学协会、国际研究型大学联盟、环太平洋大学联盟、21世纪学术联盟、东亚四大学论坛、国际公立大学论坛、中俄综合性大学联盟成员。北京大学创立于1898年维新变法之际，初名京师大学堂，是中国近现代第一所国立综合性大学，创办之初也是国家最高教育行政机关。1912年改为国立北京大学。1937年南迁至长沙，与国立清华大学和私立南开大学组成国立长沙临时大学，1938年迁至昆明，更名为国立西南联合大学。1946年复员返回北平（现北京）。1952年经全国高校院系调整，成为以文理基础学科为主的综合性大学，并自北京沙滩等地迁至现址。2000年与原北京医科大学合并，组建为新的北京大学。\n[1]\xa0\n北京大学是新文化运动的中心和五四运动的策源地，最早在中国传播马克思主义和科学、民主思想，是创建中国共产党的重要基地之一。长期以来，北京大学始终与中国和中国人民共命运，与时代和社会同前进，恰如蔡元培先生所言：“大学者，囊括大典，网罗众家之学府也……此思想自由之通则，而大学之所以为大也。\n[2]',
养计划、国家大学生创新性实验计划、国家级大学生创新创业训练计划、国家建设高水平大学公派研究生项目、中国政府奖学金来华留学生接收院校。\n[1-3]\xa0\n学校的前身是1902年创立的京师大学堂师范馆，1908年改称京师优级师范学堂，独立设校，1912年改名为北京高等师范学校。1923年学校更名为北京师范大学。1931年、1952年北平女子师范大学、辅仁大学先后并入北京师范大学。1959年，被中央确定为首批全国重点大学。2017年，学校进入国家“世界一流大学”建设A类名单。\n[1]\xa0\n\n[4]\xa0\n据2019年12月学校官网显示，北京师范大学北京校区占地面积1191亩（海淀校园、西城校园、昌平校园G区），另建有北京师范大学珠海校区；全日制在校生24000余人，其中本科生10105人、研究生12756人、长期留学生1600余人；下设3个学部、23个学院、2个系、11个研究院（所）；有博士后科研流动站25个，一级学科博士点31个，二级学科博士点114个，一级学科硕士点39个，二级学科硕士点146个；开设本科专业74个。\n[1]\xa0\n\n[5-7]',
#    'motto': '学为人师、行为世范'},
#   {'_id': 'S_8',
#    'name': '台湾交通大学',
#    'about': '台湾交通大学（National Chiao Tung University，缩写为NCTU），简称台交，位于中国台湾省新竹市，是台湾顶尖研究型重点大学之一，与台湾清华大学及新竹科学工业园区相邻，与中国大陆四所交大共同联合成立“交通大学校友总会”。\n[1]\xa0\n台湾交通大学为中等规模之研究性大学，以理工著称，在电子、资通讯及光电领域居于世界前列。\n[1-3]\xa0\n学校源头为1896年创立于上海的南洋公学、1896年创立于唐山的山海关北洋铁路官学堂。两岸分治后，上海原址改组为西安交通大学和上海交通大学。唐山、北京原址分别改组为西南交通大学和北京交通大学。1958年，交通大学继政治大学及清华大学之后在台复校，校址选定新竹市。\n[4]\xa0\n根据2016年5月学校官网显示，学校有光复校区、博爱校区、六家校区、台北校区、台南校区五个校区，校园占地面积88万平方米，校舍面积47.6024万平方米；开设18个学系，24个研究所；有教师715人，学生14141人。\n[5]\xa0\n2019年度，台湾交通大学位列2020QS世界大学排名第227位，2019世界大学学术排名501-600位。\n[6-7]',
#    'motto': ''},
#   {'_id': 'S_9',
#    'name': '暨南大学',
#    'about': '暨南大学是中国第一所由政府创办的华侨学府。“暨南”二字出自《尚书·禹贡》：“东渐于海，西被于流沙，朔南暨，声教讫于四海。”意即面向南洋，将中华文化远播到五洲四海。学校目前是中央统战部、教育部、广东省共建的国家“双一流”建设高校，直属中央统战部管理',
#    'motto': '忠信笃敬'},
#   {'_id': 'S_10',
#    'name': '国际关系学院',
#    'about': '国际关系学院（University of International Relations），简称“国关”，地处北京市西郊风景区，由中华人民共和国教育部直属，为财政部6所“小规模试点高校“之一，是以外语、国际问题为教学科研的全国重点大学。国际关系学院曾为诞生新中国第一批“将军大使”开办培训班；五十年代首创侧重外国当代语言学习的教学方法；1964年，被列为全国重点高校；改革开放初期率先完成从单纯外语专业向复合型涉外专业的转型。国际关系学院多次受到党和国家领导人的重视和关怀，周恩来总理曾亲自批准建校并到校视察；陈毅元帅亲笔题写院名；江泽民总书记1994年亲笔题词：“努力把国际关系学院办成富有特色的一流大学”。根据2015年3月学校官网显示，校园占地面积近200亩，校舍建筑面积10万余平方米；辖8个教学系部，开办10个本科专业；图书馆藏书37万册；有在校全日制研究生近500余人。\n[1]',
#    'motto': '忠诚 勤奋 求实 创新'},
#   {'_id': 'S_11',
#    'name': '华南理工大学',
#    'about': '华南理工大学（South China University of Technology），简称“华工”，位于广州市，由中华人民共和国教育部直属，是教育部与广东省人民政府共建的全国重点大学，位列国家“双一流”（A类）、“211工程”、“985工程”，入选高等学校学科创新引智计划、卓越工程师教育培养计划、卓越法律人才教育培养计划、新工科研究与实践项目、国家建设高水平大学公派研究生项目、中国政府奖学金来华留学生接收院校
学与原云南工业大学合并组建新的昆明理工大学。2004年12月，云南省分析测试中心成建制并入。\n[2]\xa0\n根据2020年7月学校官网显示，学校有呈贡、莲华、新迎三个校区，占地3915余亩；设有研究生院、1个学部、26个学院、1个教学部、7个研究院、13个临床教学基地（含9个附属医院、3个教学医院、1个实习医院）、107个本科专业；有博士后科研流动站11个，一级学科博士点17个，专业学位博士点1个，一级学科硕士点41个，专业学位硕士点21个；有教职工3823人，其中，专任教师2383人；全日制在校本科学生32352人，博士、硕士研究生 13062人，2019年有各类长短期留学生1658人。\n[2]',
#    'motto': ''},
#   {'_id': 'S_37',
#    'name': '哈尔滨工业大学',
#    'about': '哈尔滨工业大学（Harbin Institute of Technology），由工业和信息化部直属的全国重点大学，位列国家首批世界一流大学建设高校A类、985工程、211工程，九校联盟、环太平洋大学联盟、中国大学校长联谊会、卓越大学联盟、全球能源互联网大学联盟、中俄工科大学联盟、中国-西班牙大学联盟、中国人工智能教育联席会创始成员，入选珠峰计划、强基计划、2011计划、111计划、卓越工程师教育培养计划、国家大学生创新性实验计划、国家建设高水平大学公派研究生项目、新工科研究与实践项目、中国政府奖学金来华留学生接收院校、全国深化创新创业教育改革示范高校等，是首批设有研究生院、拥有研究生自主划线资格的高校，首批学位授权自主审核单位。学校始建于1920年，1951年被确定为全国学习国外高等教育办学模式的两所样板大学之一，1954年进入国家首批重点建设的6所高校行列。1996年进入国家”211工程“首批重点建设高校。1999年被确定为国家首批”985工程“重点建设的9所大学之一。2000年与哈尔滨建筑大学合并组建新的哈尔滨工业大学。2017年入选“双一流”建设A类高校名单。 \n[1-3]\xa0\n截至2018年5月，哈工大有哈尔滨、威海、深圳三个校区；本部校园面积5212.35亩，建筑面积202.69万平方米；专任教师3045人，在校学生46138人。\n[2]\xa0\n\n[4-7]',
#    'motto': ''},
#   {'_id': 'S_38',
#    'name': '中国农业大学',
#    'about': '中国农业大学（China Agricultural University），简称“中国农大”（CAU），坐落于北京市，学校是中华人民共和国教育部直属，中华人民共和国水利部、原中华人民共和国农业部和北京市共建的一所全国重点大学，位列“双一流”建设高校、“985工程”、“211工程”，入选“基础学科招生改革试点”、“2011计划”、“111计划”、卓越工程师教育培养计划、卓越农林人才教育培养计划、国家建设高水平大学公派研究生项目、中国政府奖学金来华留学生接收院校、国家大学生文化素质教育基地，为中国―加州大学系统"10+10"合作科研联盟成员高校。\n[1-3]\xa0\n中国农业大学肇始于1905年成立的京师大学堂农科大学。1949年9月，北京大学农学院、清华大学农学院和华北大学农学院合并成立北京农业大学。1952年10月，北京农业大学农业机械系与华北农业机械专科学校、中央农业部机耕学校合并成立北京机械化农业学院，同年11月，平原农学院并入北京机械化农业学院，1953年7月更名为北京农业机械化学院，1985年10月更名为北京农业工程大学。1995年9月，北京农业大学和北京农业工程大学合并组建中国农业大学。截至2019年12月，学校占地125万平方米，校舍面积123万平方米；设有19个学院，开办本科专业66个；有全日制本科生12182名，全日制研究生8930名；有专任教师1860人；有一级学科博士学位授权点21个、一级学科硕士学位授权点32个；馆藏图书近200万册。\n[4]',
#    'motto': ''},
#   {'_id': 'S_39',
#    'name': '湖北大学',
#    'about': '湖北大学（Hubei University）简称“湖大”\n[1]\xa0\n，是中华人民共和国教育部与湖北省人民政府共建的省属重点综合性大学，位列湖北省“双一流”建设高校，入选国家“中西部高校基础能力建设工程”、“111计划”、湖北省2011计划、国家级大学生创新创业训练计划、国家级新工科研究与实践项目、数据中国“百校工程”，是全国深化创新创业教育改革示范高校、中国政府奖学金来华留学生接收院
#    'motto': ''},
#   {'_id': 'S_57',
#    'name': '麻省理工学院',
#    'about': '麻省理工学院（Massachusetts Institute of Technology），简称“麻省理工”（MIT），位于美国马萨诸塞州波士顿都市区剑桥市，主校区依查尔斯河而建，是世界著名私立研究型大学。\n[1-3]\xa0\n麻省理工学院创立于1861年，早期侧重应用科学及工程学，在第二次世界大战后，麻省理工学院倚靠美国国防科技的研发需要而迅速崛起。\n[4-5]\xa0\n在二战和冷战期间，麻省理工学院的研究人员对计算机、雷达以及惯性导航系统等科技发展作出了重要贡献。\n[5-7]\xa0\n麻省理工学院素以顶尖的工程学和计算机科学而著名，拥有麻省理工人工智能实验室（MIT CSAIL）、林肯实验室（MIT Lincoln Lab）和麻省理工学院媒体实验室（MIT Media Lab），其研究人员发明了万维网、GNU系统、Emacs编辑器、RSA算法等等。\n[8-13]\xa0\n 该校的计算机工程、电机工程等诸多工程学领域在2019-20年世界大学学术排名中位列世界前五，在2018-19年US News美国研究生院排名中位列工程学第一、计算机科学第一，与斯坦福大学、加州大学伯克利分校一同被称为工程科技界的学术领袖。\n[14-18]\xa0\n 截止至2019年10月，麻省理工学院的校友、教职工及研究人员中，共产生了97位诺贝尔奖得主（世界第五）、8位菲尔兹奖得主（世界第八）以及26位图灵奖得主（世界第二）。\n[19]\xa0\n麻省理工学院位列2020-21年度QS世界大学排名第一\n[20]\xa0\n 、软科世界大学学术排名第四\n[21]\xa0\n、THE世界大学排名第五\n[22]\xa0\n、U.S. News世界大学排名第二\n[23]\xa0\n。同时列2020THE世界大学声誉排名世界第二\n[3]\xa0\n。',
#    'motto': 'Mind and Hand'},
#   {'_id': 'S_58',
#    'name': '澳门大学',
#    'about': '澳门大学（Universidade de Macau / University of Macau），简称澳大，是澳门国际化综合性公立大学，为中欧商校联盟、“一带一路”国际科学组织联盟、粤港澳高校联盟、粤港澳大湾区西岸科技创新和人才培养合作联盟创始成员和亚太高校书院联盟成员，是澳门第一所获AACSB及AMBA认证的大学。\n[1-2]\xa0\n澳门大学前身为1981年3月28日成立的东亚大学，1991年由私立转为公立并更名为澳门大学。2014年8月正式迁入位于横琴岛的新校区。学校校园面积1.09 平方公里\n[3]\xa0\n。澳门大学设有人文学院、工商管理学院、教育学院、健康科学学院、法学院、社会科学学院、科技学院、荣誉学院，以及研究生院和持续进修中心。研究机构设有中华医药研究院、应用物理及材料工程研究院、协同创新研究院、微电子研究院、澳门研究中心、亚太经济与管理研究所、人文社科高等研究院。',
#    'motto': ''},
#   {'_id': 'S_59',
#    'name': '中国人民解放军海军航空大学',
#    'about': '中国人民解放军海军航空大学是海军指挥与工程技术人才培养的主要基地和航空航天领域科研中心之一，是一所以培养海军航空兵和岸防兵初中级指挥军官、飞行军官、参谋军官、空中战勤军官和航空航天工程技术军官为主的高等军事院校，是海军航空兵、岸防兵战斗力建设的重要源头。2017年，军队院校调整改革，中国人民解放军海军航空大学由海军航空兵学院和海军航空工程学院重组而成。截至2017年5月，学校开设23个本科专业，拥有6个博士后科研流动站，
#    'motto': ''},
#   {'_id': 'S_63',
#    'name': '学堂在线',
#    'about': '学堂在线是由清华大学研发出的中文MOOC（大规模开放在线课程，简称慕课）平台，是教育部在线教育研究中心的研究交流和成果应用平台，\n[1]\xa0\n于2013年10月10日正式启动，面向全球提供在线课程。任何拥有上网条件的学生均可通过该平台，在网上学习课程视频。\n[2]\xa0\n目前，学堂在线运营了来自清华大学、北京大学、复旦大学、中国科技大学，以及麻省理工学院、斯坦福大学、加州大学伯克利分校等国内外一流大学的超过3000门优质课程，覆盖13大学科门类。\n[1]\xa0\n2020年4月20日，学堂在线国际版正式发布。\n[3]',
#    'motto': ''},
#   {'_id': 'S_64',
#    'name': '湖南大学',
#    'about': '湖南大学（Hunan University），简称“湖大”，坐落于长沙市，是教育部直属全国重点大学，教育部、工业和信息化部、湖南省人民政府、国家国防科技工业局共建高校，位列国家“世界一流大学建设高校”、“985工程”、“211工程”，入选国家“2011计划”、“111计划”、卓越法律人才教育培养计划、卓越工程师教育培养计划、国家建设高水平大学公派研究生项目、新工科研究与实践项目、全国深化创新创业教育改革示范高校、全国创新创业典型经验高校、全国高校实践育人创新创业基地、中国政府奖学金来华留学生接收院校、国家大学生创新性实验计划，高校国家知识产权信息服务中心。\n[1-2]\xa0\n湖南大学办学起源于公元976年创建的岳麓书院，历经宋、元、明、清等朝代的变迁，1897年创办新式高等学校时务学堂，1903年岳麓书院等合并改制为湖南高等学堂。1912年成立湖南高等师范学校。1926年成立省立湖南大学。1937年成为国民政府教育部16所国立大学之一.1949年9月，国立湖南大学更名为湖南大学。1950年8月20日,毛泽东同志亲笔题写校名。2000年，湖南大学与湖南财经学院合并组建成新的湖南大学。\n[3-4]\xa0\n学校占地面积240万平方米，建筑面积145万平方米；设有研究生院和25个学院；本科招生专业63个；拥有一级学科博士点28个、专业学位博士点3个、一级学科硕士点35个、专业学位硕士点26个；建有国家重点学科一级学科2个、国家重点学科二级学科14个、博士后科研流动站28个；有教职工近4000人，有全日制在校学生36000余人。',
#    'motto': '实事求是，敢为人先'},
#   {'_id': 'S_65',
#    'name': '南京大学',
# ...
#     '所以在这种情况下我们可以发现什么问题 ',
#     '就是说这里面因为这个n',
#     '是运行的时候才知道  ',
#     '所以它是作为参数传进来   ',
#     '所以n不是个常量  ',
#     '编译的时候不知道常量  ',
#     '所以参数作为变量取得  ',
#     '在这种情况下   ',
#     '你就不能完全用leal或者类似于',
#     '这种指令在里面进行运算了  ',
#     '所以你需要用套乘法来做 ',
#     '因为它是个变量  ',
#     '所以要用个乘法操作来做  ',
#     '那相对于刚才这个来法    ',
#     '算法计算复杂上面要复杂一点   ',
#     '耗费的时间更长一点  ',
#     '一方面相当于它多了个参数   ',
#     '变量或是参数  ',
#     '另外对于它相关的一些运算   ',
#     '尤其跟乘法相关的  ',
#     '需要用乘法指令来完成  ',
#     '而不能用类似于leal这种地址计算指令',
#     '来对它进行运算  ']},
#   {'_id': 'F583D1EE366342779C33DC5901307461',
#    'name': '无符号整数与带符号整数（一）',
#    'text': ['再继续往下走',
#     '那么无符号数的和带符号数',
#     '也就是补码表示的取值范围也是这个样子',
#     '无符号数呢因为我们说过啦',
#     '它是每个位串0101',
#     '乘上它二进制的这个权重',
#     '那么这样的话它肯定是大于等于0的',
#     '所以说它的最小数就是0 全0 一串0 ',
#     '最大那个呢就是全1 就是2的w次方减1',
#     '这个很容易算出来',
#     '补码呢稍微复杂一点点',
#     '它里面当然有0啦 ',
#     '但是因为它上面有个符号位',
#     '可以表示正负 那这种情况下的话呢',
#     '补码四个数里头 如果这个位宽确定的话',
#     '它最小数呢是1全0',
#     '1全0这个值是多少呢 负的2 W减1 次方',
#     '这个值怎么算实际上很简单',
#     '你把它按位取反再加个1 就是了',
#     '就是它的绝对值就是它的',
#     '这个位串表示的按位取反加个1啦',
#     '实际上就是它自个儿啦',
#     '绝对值是它一样的 ',
#     '前面加个负号就可以啦',
#     '那么最大数呢 是2的 W减1次方 再减1',
#     '就是0打头后面是全1 我们说过啦',
#     '第一个 因为你是最大数嘛',
#     '一定是个正数嘛 所以你第一位肯定是0',
#     '那么这种情况下 ',
#     '最大这个数呢就是后面全部占 ',
#     '全部是占1 那么它只能是这个数',
#     '那这个时候呢稍微注意一点点是什么呢',
#     '就是带符号数这个补码表示啊',
#     '它的正负的数的这个取值范围并不对称',
#     '并不严格对称 差了一个1',
#     '从绝对值上来讲的话',
#     '负数表示的范围大了那么1',
#     '因为当中有个0在那边嘛',
#     '还有呢一个数挺有意思就是负1',
#     '负1是全1 但为什么是全1呢',
#     '你这个绝对值 就算它的绝对值嘛',
#     '它的绝对值就是它的按位取反加1嘛',
#     '就是全1按位取反就是全0 全0加1',
#     '那就是1嘛 它是负的那就是负1',
#     '所以负1应该是全1这种表示方式',
#     '那么假设如果字长为16的话呢',
#     '这些数的这些值都给大家算出来啦',
#     '给大家有一个感性的认识就在这个表上头',
#     '回去可以慢慢看',
#     '然后呢这里面的是一个比较有意思的题目',
#     '我觉得啊 个人觉得 ',
#     '无符号数与带符号数的转换',
#     '这一点呢就是大家要注意一点 就是说',
#     '所谓无符号数与带符号数的转换',
#     '它的二进制位串的表示是不变的',
#     '就是你C里面写个等号 ',
#     '把一个signed转换成一个unsigned',
#     '如果它的位长 只要它的',
#     '位长相等 那就 所谓转换就是说',
#     '它的位串本身没有一个位置会发生变化',
#     '那你怎么说它一个带符号一个不带符号呢',
#     '也就是说 在硬件表示的层面来看',
#     '就是说你这个 一个整数',
#     '不管它带不带符号',
#     '放在硬件这个存储的空间里',
#     '就是内存里面或寄存器里头',
#     '在硬件看起来你就是个01串',
#     '它看不出来你这个01串是带不带符号的',
#     '没这概念 啊 没这概念 它没有这个概念',
#     '那你所谓这个转换是什么意思呢',
#     '就实际上就是说 你对它的解释不一样',
#     '严格来说比方说在C层面',
#     '一个signed一个unsigned',
#     '两个相互转换的话呢 实际上就是',
#     '编译器对它的解释不一样',
#     '我们把一个位串解释成',
#     '比方说是这个带符号的',
#     '那就按照刚才我所说的那个补码去算',
#     '那如果把它解释成是不带符号的',
#     '那就按照刚才那个原码 去算',
#     '刚才我们说过啦 不再往后谈了',
#     '实际上就这样的东西 这样一来的话呢',
#     '我想给大家留一个问题 ',
#     '就慢慢思考 以后课堂里面我会再讲',
#     '就是说 既然你这个整型数啊',
#     '在机器层面 它是没有区分的',
#     '因为它从表达上 0101这个位串',
#     '不管是带不带符号 机器层面看不出来啊',
#     '就一个01串 就你解释不了',
#     '同时在指令层面 比如说你做个加减',
#     '你做个带符号数的加减和不带符号的加减',
#     '因为补码有比较好的性质啊',
#     '就它的这个加减运算能运算',
#     '它的这个算法跟这个原码是一模一样的',
#     '也就是说一套电路就能完成 ',
#     '这样呢 在汇编层面看起来呢 你一个加法',
#     '它就是能够处理 ',
#     '带符号数和不带符号数都能够处理',
#     '也就是说在这个 在你存储层面',
#     '和在基本的一些运算指令看起来',
#     '带符号数和不带符号数没有区别',
#     '那么问题就来了 那没有区别那你最终',
#     '当然在你C语言层面是有区别的',
#     'signed unsigned这是有区别的',
#     '那个这个区别是谁来做呢',
#     '我想大家来想想这个问题',
#     '我们在后续课程当中会慢慢的',
#     '解答这个问题 当然实际上也不困难',
#     '总的来说就是无符号数带符号数',
#     '所谓两者间的转换',
#     '实际上没有什么转换 就解释不一样',
#     '在硬件层面看起来它们都是一回事儿',
#     '就是一个0101串 什么都不动',
#     '只是我解释它们这个值不一样',
#     '当然这样子的话呢就是',
#     '虽然它的0101串本身是不变的',
#     '但是因为它这个解释',
#     '这个值的算法不一样',
#     '所以呢 无符号数带符号数',
#     '如果它们位宽相等的话',
#     '它们的取值范围的对应关系是这个样子',
#     '这个图当然画得比较直观啦 ',
#     '就是说 你说这个带符号数',
#     '带符号数如果是大于等于0的话呢',
#     '那么它们转换成无符号数不变',
#     '还是这个value还是这个值',
#     '但是呢 如果你的带符号数是小于0的话',
#     '因为无符号数里面没有小于0这个东西',
#     '没有这个概念 它小于0这个值呢',
#     '怎么着 一下就翻过去 就变成大于0了',
#     '它就变成比较大的那些数了',
#     '大家看一下 它的负1呢 就变成啦',
#     '这个无符号数里面最大的那一个',
#     '对 就变成它最大的那一个',
#     '这个画得比较明显',
#     '这个当然我们回去可以稍微推算一下',
#     '这个比较清楚啦 那接下来再讲讲看',
#     '就是我们说过 这门课很大程度上呢',
#     '要从C语言的层面 来看计算机程序',
#     '里面的数值 数据在机器层面的运算',
#     '表示 这个东西 那么',
#     '我们回过头来再从C层面来看',
#     '就是C语言当中的无符号数带符号数',
#     '它是怎么 有些什么样的特点',
#     '这个呢实际上大家 请大家注意就是说',
#     'C里面 这个常数 就是常数 常量',
#     '你定义的或者说你直接在算式里面给出的',
#     '默认呢是一种带符号数',
#     '除非呢它有强制 有个U作为后缀',
#     '那么就把它作为这个无符号数来区别',
#     '就是默认的是带符号数',
#     '除非有个U作为后缀 还有一条',
#     '就是我们很多人不一定都注意得到啦',
#     '就是如果无符号数与带符号数混合使用',
#     '那么带符号数就默认转换成无符号数',
#     '包括两个数比较 比大比小',
#     '那么这样一来的话呢就是给大家',
#     '看一下这个实例 看底下这个表格啦',
#     '就是这个小小的练习',
#     '假设我们有一系列的两列的这个常数',
#     '就w的宽度呢就是它的 机器字长是32位',
#     '那就问你 ',
#     '这两列常数它的分别对应的关系是什么',
#     '就比大比小 那么怎么样子呢',
#     '首先就是说 第一行',
#     '0跟0 这大家想想看 这个肯定是相等',
#     '我们看直接把答案给出来吧',
#     '0 0是相等 都是unsigned',
#     '大家可以想一想 ',
#     '0跟0你说比出来不一样就不行啦',
#     '第二呢就是负1对0',
#     '那么负1 0呢两个都是这个常数',
#     '常数嘛当然默认情况下是算signed',
#     '那么signed话呢负1当然小于0啦',
#     '下面一个就复杂一点啦 就是负1跟0U',
#     '本来默认都是signed的话',
#     '你强制的转换了有一个U在里头',
#     '那么这样子 就是0U就是unsigned',
#     'unsigned跟signed一块儿比较',
#     '一块儿运算的话呢 ',
#     '就是大家默认转换成unsigned',
#     '那么一旦转换成unsigned的话事情就坏了',
#     '我们说过这个负1 这个signed这个数',
#     '如果转换成unsigned的话',
#     '变成多少 就是全1啦 因为它 ',
#     '它的位串 负1就是全1嘛',
#     '全1我们转换成这个unsigned',
#     '这个二进制位串的话呢 还是个全1',
#     '但解释不一样啦 它就变成最大的一个',
#     '那个unsigned这个数啦 所以是大于',
#     '以下也以此类推 大家去看一看',
#     '2147483647是个什么呢',
#     '大家看一看 这是一个很特殊的一个数',
#     '是某个什么什么最大的数',
#     '正是因为这个数在 同时再结合',
#     '我刚才说过啦 相同位宽情况下',
#     '带符号数不带符号数 带符号数',
#     '它们的正的这个值的取值范围比',
#     '负的这个值的取值范围要小那么一个',
#     '所以这一点抓住之后 底下这些判断 ',
#     '我们能够非常容易的做出来',
#     '这个大家可以作为一个练习',
#     '回去慢慢的去思考一下',
#     '那么咱们再讲讲看',
#     '既然讲到无符号数带符号数',
#     '又讲到这个C语言啦 ',
#     '那么就请问一下就是说 我们在什么时候',
#     '在C程序里面要采用这个无符号数',
#     '这个当然我们采用了一些说法就是说',
#     '个人观点 就是说',
#     '能不用符号数就不用符号数',
#     '除非 你是做模运算',
#     '模运算很清楚 取模 一个数',
#     '取模运算的话因为它没有',
#     '这个负的这个概念了',
#     '还有个就是按位运算 按位',
#     '就是把它作为 这不是一个数啦',
#     '就是一个0101 一个二进制串 ',
#     '按位做运算 这是可以的',
#     '除了这两类之外呢 ',
#     '就尽量不要用无符号数 就是说 ',
#     '不能仅仅因为取值范围是非负而使用',
#     '这边就给出两个例子 实际上我们就是',
#     '那个课本上也有 参考书上也有这个例子',
#     '就是什么意思呢 示例一',
#     '我们做一个循环的一个操作 一个判断',
#     '一个循环 做一个这个数组的一个累加',
#     '这么个东西 ',
#     '我们把循环变量呢定义为unsigned int',
#     '那么然后呢 ',
#     '一个判断条件就是i大于等于0',
#     '如果i大于等于0那么继续 否则就退出',
#     '那这样明显就有一个问题 什么呢 就是',
#     'i是unsigned unsigned这个数',
#     '这个类型的数 它永远都是大于等于0的',
#     '它没有负的这个说法 你大于等于0',
#     '0呢 常数 常数默认也是什么啊',
#     '这个 是signed的 ',
#     '但是signed跟unsigned一块儿',
#     '进行运算的话 都转换成unsigned',
#     '这问题就在这个地方',
#     '也就是说 你会陷入一个什么啊 ',
#     '无限循环 i退不出去',
#     'i因为永远大于等于0嘛',
#     '那么有可能就导致就是什么',
#     '你取值的范围可能会超出',
#     '就可能你最后是a[i]',
#     '这个下标会变得那个什么',
#     '所以会导致一个错误',
#     '第二就是示例二',
#     '示例二呢稍微绕一点点',
#     '我们倒是把这个循环变量',
#     '定义成一个int啦 这没错 啊 int',
#     'signed的 但问题在于什么呢',
#     '它在这个条件判断的时候',
#     '它减了一个DALTA',
#     '这个DALTA呢又是sizeof',
#     'sizeof查一下 它返回的这个数据类型啊',
#     '是unsigned的 那就坏事儿啦',
#     '我们说过 int倒是signed',
#     '后面跟它一块儿运算的那个数是unsigned',
#     'signed加unsigned 在C语言的层面',
#     '那就大家统统转换成unsigned',
#     '都转成unsigned unsigned一来就坏了',
#     'unsigned永远都是大于等于0的',
#     '那这个它又退不出来了',
#     '会又造成各种各样的问题',
#     '实际上很大程度上是一种可能是一种',
#     '会越界什么之类的 ',
#     '或者这种别的这样的问题',
#     '那么在这种情况下的话呢',
#     '示例一二大家都要注意 就是说',
#     '不能仅仅因为取值范围是非负而使用',
#     '尽量我建议大家就使用 ',
#     '就是说除非你有上面两个用途',
#     '一般来说无符号数还是少用',
#     '其中这两条呢第一个问题还可以避免',
#     '就是你循环变量不要用unsigned就完了',
#     '第二可不太好说 因为你谁知道',
#     '你sizeof返回是一个unsigned值',
#     '这个都有点始料不及的 所以要注意啊',
#     '编程是一个很危险的事情',
#     '完了就讲讲看这个无符号数的加法',
#     '这个我们蛮简单的 就是 和大家讲讲 ',
#     '无符号数因为它是原码表示嘛',
#     '就0101串 那就按位加就完了',
#     '但就要注意 ',
#     '因为你这个机器表示的数据位宽有限',
#     '比如说w等于32 那么如果你有一个向30 ',
#     '就是向高一位的一个进位',
#     '那么这个进位在结果里面就被剔掉啦',
#     '就不存在啦 所以说呢',
#     '两个u加v 无符号整数相加',
#     '实际上等于它加出来这个数值啊',
#     '取模的一个2的w次方',
#     '所以说这个时候就可能产生溢出啦',
#     '就是有两个你无符号数',
#     '无符号数都大于等于0嘛 相加',
#     '如果这数比较大的话 向上有个进位的话',
#     '那这个数值就不对啦 就产生数据的溢出',
#     '当然一般情况下呢就是说在C语言里头',
#     '它默认是不检测这种溢出的',
#     '当然大家写程序的时候呢',
#     '可能稍微要注意一点就是',
#     '你所采用的这个数据类型',
#     '在你这个运算范围之内 有没有可能溢出',
#     '所以有的时候就是说你要注意一点',
#     '如果觉得不靠谱的话',
#     '再把它的这个位宽选得大一点',
#     '你就不要用int 用long long之类的',
#     ' ',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '']},
#   {'_id': 'F9053B0221C642FF9C33DC5901307461',
#    'name': '读取条件码指令-2',
#    'text': ['    ',
#     '    ',
#     '    ',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '那么读取条件码呢给大家还是一个',
#     '典型的比较简单的C语言的一个函数',
#     '咱么就看通过Gcc',
#     '把这个C函数怎么转换成什么样的一个汇编',
#     '在我们直观上就有个认识',
#     '就在C层面如果要读取 进行比大比小',
#     '两个数比大比小 ',
#     '实际上把这个数返回的话呢',
#     '在汇编层面是怎么实现的 那么再说一遍',
#     'SetX指令就是读取当前的条件码',
#     '或者条件码的一些组合',
#     '存入目的的字节寄存器',
#     '它只存入一个byte',
#     '余下的三个字节呢不会被修改',
#     '那么这个时候呢 你把一个寄存器',
#     '它的 可能最低的那个字节给改掉了',
#     '那么余下的那个高的三个字节怎么办呢',
#     '所以一般情况下我们会采用movezbl指令',
#     '对目的寄存器啊 进行高位的0扩展',
#     '就是顾名思义 我们以前课也讲过',
#     '就是最后就move 这时候叫move指令',
#     'z的话呢就是说0扩展 因为是b到l嘛',
#     '一个byte到一个doubleword',
#     '所以就把8位扩展到32位码',
#     '那怎么扩展呢就是z 叫zero 就0扩展',
#     '然后呢我们就看一下这个函数',
#     '这个函数很简单 gt 给它两个参数x y',
#     '那么如果是x大于y的话 那就返回一个1',
#     '那否则就返回0 应该就是这个来法',
#     '我们把它编译一下',
#     '就生成下面这个汇编的这个主体啦',
#     '当然我们掐头去尾 ',
#     '主要把它主体拎出来看一下',
#     '那么这里面可以看到 第一条语句',
#     '实际上很简单啦 ',
#     '就是我把eax里头设成y',
#     'ebp加8加12 虽然我们还没有讲',
#     '栈是怎么构建的 但是我们可以猜到',
#     '它肯定是在访问它的一个参数',
#     '那参数呢是y 所以把这个y值取出来',
#     '放到eax寄存器里头',
#     '第二个呢我就把这个x跟y比一下',
#     '注意是右侧的这8（&ebp）',
#     '内存里面存的这个值减去eax啦',
#     '所以是x减y了 然后呢减完之后',
#     '我用了一个setg 那这个是对的',
#     '因为什么呢 因为x y啊是带符号数',
#     '所以我用set这个什么啊',
#     'g就是Great l就是Less',
#     '用那套组合用于表示',
#     '这个带符号整数的比较结果啦',
#     '把这个条件码或者条件码的组合给它取出来',
#     '然后呢这个条件码或者条件码的组合呢',
#     '就设到al 那么al我们以前没有见过',
#     '什么叫做al 实际上就是说呢',
#     'eax寄存器我们知道 通用寄存器',
#     '32通用寄存器eax它的这个',
#     '低16位被称之为ax ',
#     '因为我们知道Intel的80X86系列',
#     '是从8086扩展出来的 从那会儿起呢',
#     '本来啊16位的通用寄存器叫做ax',
#     '扩展到32位之后呢就叫做eax',
#     '然后呢ax里头呢 高8位低8位',
#     '分别称之为ah和al 那么这个特性呢',
#     '就这个访问特性啊',
#     '一直因为要保承这种后向的兼容',
#     '所以在32位的结构下面呢',
#     '还是能够以8位的形式 来访问eax的',
#     '低8位或者说是次低8位',
#     '那名字就叫al和ah 这个都保留下来了',
#     '所以呢用setg &al',
#     '就是把我这个条件码的组合',
#     '把它当成一个byte把它读出来',
#     '设置到al寄存器里面去',
#     '然后呢用movezbl 就是把al本身',
#     '因为它只占了低八位嘛',
#     '我把它扩展到整个eax',
#     '所以把它高24位按照0扩展',
#     '那么最后结果呢反正不是0就是1',
#     '那这个很清楚 ',
#     '但如果用movsbl的话就是做符号扩展啦',
#     '但这里面是不合适 就做个0扩展就可以啦']},
#   {'_id': 'FC709B4D20772A729C33DC5901307461',
#    'name': '汇编编程示例-文件处理-6',
#    'text': ['那么就写程序了',
#     '我们要去写数据记录文件 ',
#     '首先是open file',
#     '写进去三个记录',
#     'close the file',
#     '这个程序很简单的逻辑  这个流程',
#     '首先说个records.s',
#     '这个跟刚才那个不一样',
#     '实际上它include两个.s文件',
#     '然后呢',
#     '数据段',
#     '这个地方是什么意思',
#     '就是说',
#     '当然它这个文件只是个例子只用示例了',
#     '很简单',
#     '意思是说',
#     '我的record三个record ',
#     '直接就写在你的.s文件里边去了',
#     '那怎么个意思法呢',
#     'record1',
#     '就是说我的这个人名叫Fredrick',
#     'ascii字符串类型',
#     '后面加0嘛',
#     '0结尾',
#     '然后呢',
#     '我们说过了',
#     '这个struct',
#     '它的第一个域长度应该是40 ',
#     '40的话呢',
#     'Fredrick后面加个0',
#     '就有9个byte',
#     '后边要填充31个byte',
#     '把它撑满40个byte ',
#     '所以这里边一个写法就是',
#     'rept 31',
#     'byte 0  ',
#     '就相当于',
#     '这是一个end',
#     '就是一个rept',
#     '就把byte 0 ',
#     '重复31次 ',
#     '我想你不用手写31个  太麻烦了 31次',
#     '填上  撑满40个',
#     '然后呢',
#     'Bartlett ',
#     '这相当于他的姓',
#     '姓的字符也就9个',
#     '我们说过了',
#     '他的姓也应该充满40',
#     '所以再来一遍',
#     '再撑满40个字节',
#     '后面是他的地址',
#     '撑满240字节',
#     '再后面是他的年龄',
#     '年龄long类型就是4嘛',
#     '就结束了',
#     '然后再就写record2',
#     '我们一共写三个4个0  1  2  3  4',
#     '往下是A ',
#     'ascii  1  2  3',
#     '往下走',
#     '就这么来法',
#     '这边就是我们学的这个东西',
#     '指示汇编器重复填充其与',
#     'endr 之间的内容',
#     '重复N次',
#     '重复byte 0 ',
#     '重复填充31次',
#     '就这样填满',
#     '我们就这样比较笨的方式',
#     '直接把这几个record写到这个程序里面',
#     '就写死了',
#     '好 就是一直就在写文件 写文件',
#     '写的文件写到那地方去呢',
#     '写test.dat',
#     '就是文件的名字就是它',
#     '它没有指明任何一个绝对的路径',
#     '那应该在当前的路径下',
#     '就写这个东西',
#     '然后看这个程序怎么去运行',
#     '这样啊esp到 ebp建立栈帧',
#     'subl esp减4',
#     '相当于我们在栈帧',
#     '栈上分配一个4字节局部的空间',
#     '然后呢  OK',
#     '当然这个地方就是说',
#     '我们要打开一个文件 打开这个文件',
#     '就告诉这个系统呢',
#     '如果它不存在的话',
#     '就创建它 ',
#     '然后创建它 就是为了写 ',
#     '创建它 ',
#     '就相当于指明它的一些访问权限',
#     '就在这个地方',
#     '然后呢',
#     '这个sys call打开文件sys call的返回值',
#     '放到eax里面去的',
#     '这就是打开这个文件的文件描述符',
#     '这文件描述符要存到ebp-4这个位置去',
#     '相当于存到',
#     '应该是把movl  eax存放到',
#     '我当前这个函数里面的一个局部空间',
#     '一个局部空间放进去',
#     '然后呢',
#     '我要开始写就刚才我定义了两个函数嘛',
#     '一个写write call',
#     '一个写read call',
#     '现在我要write',
#     '那怎么弄呢',
#     '两个pushl',
#     '我首先pushl一个你要写的那个文件',
#     '目标文件',
#     '然后再pushl一个record1',
#     '就是你要写的那个数据那个地址',
#     '注意record1本身就是一个地址',
#     '这个地址做为常量来传的',
#     '说它前面要加$符',
#     '然后call write_record ',
#     '但我们不添加访问值了',
#     '因为它胜利了',
#     '然后呢 ',
#     'addl esp加8  esp加8',
#     '这相当于我恢复这个栈',
#     '调用者恢复栈',
#     '还有这个规律',
#     '然后我们要把剩余几个record都写完',
#     '但是这个程序是个demo使用',
#     '就是你要写几个',
#     '你就得重复写多次',
#     '这个比较是一个比较示意程序',
#     '最后我们就是把这几个程序连接在一起',
#     '因为刚才提到过了',
#     '这个程序是由两个.o构成 ',
#     '一个是records.s ',
#     '一个是刚才调用的write-record',
#     '那个函数所对应的.s ',
#     '所以分别拿它们汇编出来一个.o',
#     '把两个用ld命令link',
#     '把两个.o连接起来',
#     '生成最终的执行文件 最终执行文件']},
#   {'_id': 'FFD6B6E681974C739C33DC5901307461',
#    'name': '程序链接-4',
#    'text': ['那么我们再讲讲看',
#     '有三种不同的对象文件',
#     '刚才我们提到过了',
#     '第一个就是从.c转换成.o',
#     '.o呢就是重定向的对象文件这么说',
#     '它是含有一定格式的代码与数据内容',
#     '可以与其它若干个重定向对象文件',
#     '一起集成为执行文件',
#     '那么一个.o',
#     '就是说重定向文件有一个',
#     '唯一的一个源文件生成',
#     '就是通过编译生成',
#     '所以我们现在可以想象',
#     '刚才说的蛮清楚了',
#     '就是说要重定向文件里头',
#     '实际上里头有大量的可以理解成',
#     '有大量的空泡',
#     '就是一些符号的一些引用的位置',
#     '你需要把这些空泡以绝对地址给它填上',
#     '就是链接来干的事',
#     '执行文件也是',
#     '含有一定格式的数据代码内容',
#     '可以直接被装载入内存并执行',
#     '一般来说执行文件是由一个',
#     '或者多个.o通过链接生成的',
#     '还有一个稍微有点特殊',
#     '就是共享对象文件',
#     '这个我们最后会解释一下',
#     '后缀.so',
#     'linux情况下后缀就是.so',
#     '就是特殊类型的重定向对象文件',
#     '可以被装载入内存后进行动态的链接',
#     '也就是说链接可以在装载时',
#     '或运行时候完成',
#     '像windows情况下呢共享对象文件',
#     '称之为动态链接库',
#     '这是什么意思呢',
#     '就是连接这个操作有的是在',
#     '实际上就是在你编译链接的时候',
#     '调gcc命令的时候',
#     '就是你在最后生成这个执行文件的时候',
#     '这个链接就做完了',
#     '这叫静态链接',
#     '那么动态链接是什么呢',
#     '就是说最终的链接的过程是在程序运行',
#     'load的时候',
#     '甚至是说你在你程序里要',
#     '使用这个函数的时候来完成',
#     '当然我们这个课上重点就讲这个前者',
#     '就是静态链接的这个过程\u3000',
#     '后者就是我们有兴趣的话',
#     '可以看看课外书去了',
#     '完了呢',
#     '就是这个对象文件它涉及到的二进制标准',
#     '叫做ELF可执行以及可链接的格式',
#     '这是一个对象文件的标准二进制格式之一',
#     '还是ECOFF之类的',
#     '大家都差不多',
#     '那么上面提到的三种文件',
#     '都可以使用这种统一的格式',
#     '也就是说它是标准了',
#     '最初呢是由',
#     'AT& T system V Unix系统里采用',
#     '这就涉及到V Unix的来源',
#     '后面又被广泛采用包括',
#     'BSD Unix这一系列',
#     '我们知道Unix系统分两个系列',
#     '包括后来的linux系统',
#     'linux系统不是unix系统',
#     '是类unix的系统',
#     '但都是广泛的采用了这种格式',
#     '那么ELF文件格式的大致的形式',
#     '是什么样子',
#     '首先它里面我们就不细说了啊',
#     '这是ELF文件的一个格式',
#     '但里面分成多个段',
#     '有的头啊header table',
#     '主要我们知道有这些个',
#     '就是说它首先里面包含一个正文段',
#     '就是text section',
#     '就是你最终的这个文件',
#     '它里面所有的代码都组装成这个正文段',
#     '还有呢',
#     '叫什么',
#     'Read only data就只读数据段',
#     '就是Read only的数据都放到一块',
#     '数据段',
#     '数据段一般来说呢',
#     '就是初始化处理过的全局的变量',
#     '初始化过的全局变量',
#     '还有一个叫bss段',
#     '它里面存放的也是全局变量',
#     '但这是没有初始化过的',
#     '这个我记得我以前讲过',
#     '初始化过的和没有初始化过',
#     '全局的数据进行分区区分的话',
#     '是有好处的',
#     '因为你想想看',
#     '如果一个全局数据它被初始化了',
#     '比如说一个数组',
#     '每一个元素都被初始化了',
#     '那么实实在在的',
#     '必须在你对象文件里面就占有这些位置',
#     '因为它初始化的值被填上了',
#     '但是如果你只声明一个数组',
#     '长度很长还不管有多长',
#     '但是没有初始化',
#     '那么就不需要在你的执行文件里',
#     '实实在在的放这个数',
#     '因为还没这些数',
#     '你就是放一个描述就行了',
#     '比方这里面我声明了',
#     '一个长度为1K的数组',
#     '但我并不需要给它留一个1K的位置出来',
#     '因为没有被初始化过',
#     '但如果是初始化的话呢',
#     '就给它留这个位置了',
#     '所以呢这两个给它分开 这两个给它分开',
#     '在往下的话呢有一个比较重要',
#     '这还没有说完',
#     '这是续在前面讲',
#     '就是第一个是什么',
#     '就是符号表',
#     '刚才我们说过了',
#     '就是每一个ELF文件它都有一个符号表',
#     '符号表里面就给出什么呢',
#     '它里面就声明了哪些',
#     '可以被外界引用的一些符号',
#     '就在里头',
#     '搁在里头',
#     '这样的话你做符号解析的时候',
#     '大家相互查这个头',
#     '那么下面几个还蛮有意思的',
#     'rel text section和rel点data点section',
#     '这个刚才提到过了',
#     '实际上就是大致这么一说',
#     '因为刚才说过了',
#     '就是说一个.c转换到.o的时候',
#     '里面有大量的符号需要被重定位',
#     '那哪些需要重定位呢',
#     '它这些相关的信息',
#     '就放在rel text section',
#     '如果你是代码段里面的话',
#     '或就放在rel data section里面',
#     '如果你属于数据段的话',
#     '就放到这里头',
#     '那后面两个对我们来说就不涉及了']}]}

# %%
for k, v in sample.items():
    if isinstance(v, list):
        print(f"Course: {len(v)} {k}")
# Out:
# Course: 1 fields
# Course: 140 resources
# Course: 429 schools
# Course: 2 teachers
# Course: 7346 users
# Course: 71 comments
# Course: 11 replies
# Course: 26 exercises
# Course: 130 videos

# %%
import torch
from torch_geometric.data import HeteroData
import torch_geometric.nn as gnn
import torch_geometric.transforms as T

def to_hetero_data(sample: dict):
    data = HeteroData()
    data["course"].x = encode_course(sample["course"])
    data["field"].x = encode_fields(sample["fields"])
    data["resource"].x = encode_resources(sample["resources"])
    data["school"].x = encode_schools(sample["schools"])
    data["teacher"].x = encode_teachers(sample["teachers"])
    data["user"].x = encode_users(sample["users"])
    data["comment"].x = encode_comments(sample["comments"])
    data["reply"].x = encode_replies(sample["replies"])
    data["exercise"].x = encode_exercises(sample["exercises"])
    data["video"].x = encode_videos(sample["videos"])

    if (edge := course_field_edges(sample["fields"])).size(0) == 2:
        data["course", "edge", "field"].edge_index = edge
    if (edge := course_resource_edges(sample["resources"])).size(0) == 2:
        data["course", "edge", "resource"].edge_index = edge
    if (edge := course_teacher_edges(sample["teachers"])).size(0) == 2:
        data["course", "edge", "teacher"].edge_index = edge
    if (edge := course_school_edges(sample["course"], sample["schools"])).size(0) == 2:
        data["course", "edge", "school"].edge_index = edge
    if (edge := course_user_edges(sample["users"])).size(0) == 2:
        data["course", "edge", "user"].edge_index = edge
    if (edge := course_comment_edges(sample["comments"])).size(0) == 2:
        data["course", "edge", "comment"].edge_index = edge
    if (edge := comment_reply_edges(sample["comments"], sample["replies"])).size(0) == 2:
        data["comment", "edge", "reply"].edge_index = edge
    if (edge := user_comment_edges(sample["users"], sample["comments"])).size(0) == 2:
        data["user", "edge", "comment"].edge_index = edge
    if (edge := user_reply_edges(sample["users"], sample["replies"])).size(0) == 2:
        data["user", "edge", "reply"].edge_index = edge
    if (edge := school_user_edges(sample["schools"], sample["users"])).size(0) == 2:
        data["school", "edge", "user"].edge_index = edge
    if (edge := school_teacher_edges(sample["schools"], sample["teachers"])).size(0) == 2:
        data["school", "edge", "teacher"].edge_index = edge
    if (edge := resource_exercise_edges(sample["resources"], sample["exercises"])).size(0) == 2:
        data["resource", "edge", "exercise"].edge_index = edge
    if (edge := resource_video_edges(sample["resources"], sample["videos"])).size(0) == 2:
        data["resource", "edge", "video"].edge_index = edge

    data = T.ToUndirected()(data)
    return data

# %%
data = to_hetero_data(sample)
data
# Out:
# HeteroData(
#   course={ x=[1, 2048] },
#   field={ x=[1, 1024] },
#   resource={ x=[140, 1024] },
#   school={ x=[429, 2048] },
#   teacher={ x=[2, 2048] },
#   user={ x=[7346, 3] },
#   comment={ x=[71, 1024] },
#   reply={ x=[11, 1024] },
#   exercise={ x=[26, 3072] },
#   video={ x=[130, 2048] },
#   (course, edge, field)={ edge_index=[2, 1] },
#   (course, edge, resource)={ edge_index=[2, 140] },
#   (course, edge, teacher)={ edge_index=[2, 2] },
#   (course, edge, school)={ edge_index=[2, 1] },
#   (course, edge, user)={ edge_index=[2, 7346] },
#   (course, edge, comment)={ edge_index=[2, 71] },
#   (comment, edge, reply)={ edge_index=[2, 11] },
#   (user, edge, comment)={ edge_index=[2, 71] },
#   (user, edge, reply)={ edge_index=[2, 11] },
#   (school, edge, user)={ edge_index=[2, 1180] },
#   (school, edge, teacher)={ edge_index=[2, 2] },
#   (resource, edge, exercise)={ edge_index=[2, 26] },
#   (resource, edge, video)={ edge_index=[2, 130] },
#   (field, rev_edge, course)={ edge_index=[2, 1] },
#   (resource, rev_edge, course)={ edge_index=[2, 140] },
#   (teacher, rev_edge, course)={ edge_index=[2, 2] },
#   (school, rev_edge, course)={ edge_index=[2, 1] },
#   (user, rev_edge, course)={ edge_index=[2, 7346] },
#   (comment, rev_edge, course)={ edge_index=[2, 71] },
#   (reply, rev_edge, comment)={ edge_index=[2, 11] },
#   (comment, rev_edge, user)={ edge_index=[2, 71] },
#   (reply, rev_edge, user)={ edge_index=[2, 11] },
#   (user, rev_edge, school)={ edge_index=[2, 1180] },
#   (teacher, rev_edge, school)={ edge_index=[2, 2] },
#   (exercise, rev_edge, resource)={ edge_index=[2, 26] },
#   (video, rev_edge, resource)={ edge_index=[2, 130] }
# )

# %%
from utils.utils import binary_hetero_data
from tqdm import tqdm
import joblib
import os

os.makedirs("samples", exist_ok=True)
for row in tqdm(courses.itertuples(), desc="Storing samples to disk", total=courses.shape[0]):
    course_id = row.id
    label = row.course_classification
    if os.path.isfile(f"samples/{course_id}.pkl"):
        continue

    try:
        sample = query(course_id, db)
        data = to_hetero_data(sample)
        obj = {
            "_id": course_id,
            "data": data,
            "label": label
        }
        joblib.dump(obj, f"samples/{course_id}.pkl")
    except Exception as e:
        print(f"Error processing course {course_id}: {e}")
        continue
# Out:
# Storing samples to disk:   0%|          | 0/3757 [00:00<?, ?it/s]/home/ptdat/Desktop/graph/utils/edge.py:44: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   return torch.tensor(edges).T.long()
# Storing samples to disk:   9%|▉         | 331/3757 [50:13<41:06:02, 43.19s/it]
# Error processing course C_681712: 'S_129' is not in list
# Storing samples to disk:  10%|▉         | 360/3757 [1:26:28<13:36:02, 14.41s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#      13 try:
#      14     sample = query(course_id, db)
# ---> 15     data = to_hetero_data(sample)
#      16     obj = {
#      17         "_id": course_id,
#      18         "data": data,
#      19         "label": label
#      20     }
#      21     joblib.dump(obj, f"samples/{course_id}.pkl")
#
# Cell In[4], line 11, in to_hetero_data(sample)
#       9 data["field"].x = encode_fields(sample["fields"])
#      10 data["resource"].x = encode_resources(sample["resources"])
# ---> 11 data["school"].x = encode_schools(sample["schools"])
#      12 data["teacher"].x = encode_teachers(sample["teachers"])
#      13 data["user"].x = encode_users(sample["users"])
#
# File ~/Desktop/graph/utils/encode.py:81, in encode_schools(schools)
#      78     abouts.append(school["about"])
#      79     mottos.append(school["motto"])
# ---> 81 about_embed = forward_llm(llm, abouts)
#      82 motto_embed = forward_llm(llm, mottos)
#      83 representation = torch.cat([about_embed, motto_embed], dim=-1)
#
# File ~/Desktop/venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Desktop/graph/utils/encode.py:32, in forward_llm(llm, text, batch_size, device)
#      28 for batch in chunks(text, batch_size):
#      29     model_inputs = tokenizer(
#      30         batch, return_tensors="pt", padding=True, truncation=True
#      31     ).to(device)
# ---> 32     batch_output = model.roberta(**model_inputs).last_hidden_state[:, 0, :].cpu()
#      33     output.append(batch_output)
#      34 return torch.cat(output, dim=0)
#
# KeyboardInterrupt:
