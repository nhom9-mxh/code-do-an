# %% [markdown]
# # Xây dựng các đồ thị, trong đó có 1 thực thể course làm trung tâm

# %% [markdown]
# ### Đọc file CSV chứa course ID và nhãn của course

# %%
import pandas as pd
from utils.encode import *
from utils.edge import *

courses = pd.read_csv("/home/ptdat/Desktop/graph/course_labeled.csv")[["id", "course_classification"]]
courses = courses
courses.head()
# Out:
# If you want to use `XLMRobertaLMHeadModel` as a standalone, add `is_decoder=True.`
#          id course_classification
# 0  C_655852                normal
# 1  C_655850                   bad
# 2  C_654554                normal
# 3  C_654506                   bad
# 4  C_629558                normal

# %% [markdown]
# ### Kết nối đến MongoDB (config tại file docker-compose.yml)
#
# Để mở MongoDB, chạy lệnh
# ```sh
# sudo docker compose up
# ```

# %%
from pymongo import MongoClient
from pymongo.database import Database

client = MongoClient("mongodb://root:example@localhost:27017/")
db = client["database"]

# %% [markdown]
# Hàm truy vấn các thực thể liên quan đến course có ID là *course_id*
#
# ![](graph-diagram.png)

# %%
from itertools import product
import re

def query(course_id: str, db: Database):
    # Course
    course = db["course"].find_one(
        {"_id": course_id}, 
        projection=["about", "prerequisites", "school_id", "field"])
    # Fields
    fields = course.pop("field")
    # Resources
    resources = list(db["resource"].find(
        {"course_id": course_id}, 
        projection={"title": {"$arrayElemAt": ["$titles", 0]}, "ccid": 1}))
    # School
    schools = list(db["school"].aggregate([
        {
            "$group": {
            "_id": "$name",
            "school": { "$first": "$$ROOT" }
            }
        },
        {
            "$replaceRoot": { "newRoot": "$school" }
        },
        {
            "$project": {"name": 1, "about": 1, "motto": 1}
        }
    ])) # Lấy tất cả dữ liệu school, nhưng lọc những trường bị trùng tên
    # Teachers
    teacher_ids = [re.search(r"T_\d+$", dict(i)["_id"]).group(0) for i in db["course-teacher"].find({"_id": {"$regex": f"^{course_id}"}})]
    teachers = list(db["teacher"].find(
        {"_id": {"$in": teacher_ids}}, 
        projection=["about", "job_title", "org_name"]))
    # Users
    user_ids = [re.search(r"U_\d+$", dict(i)["_id"]).group(0) for i in db["user_course"].find({"_id": {"$regex": f"^{course_id}"}})]
    users = list(db["user"].find(
        {"_id": {"$in": user_ids}, "gender": {"$in": [0, 1, 2]}}, # Chỉ lấy các gender mang mã 0, 1, 2 (chiếm đa số)
        projection=["school", "gender"]))
    # Comments
    comments = list(db["comment"].find(
        {"course_id": course_id}, 
        projection=["text", "user_id"]))
    # Replies
    comment_ids = [comment["_id"] for comment in comments]
    replies = list(db["reply"].find(
        {"comment_id": {"$in": comment_ids}}, 
        projection=["text", "user_id", "comment_id"]))
    # Exercises
    resource_ids = [resource["_id"] for resource in resources]
    exercises = list(db["problem"].find(
        {"exercise_id": {"$in": resource_ids}}, 
        projection=["title", "content", "typetext", "exercise_id"]))
    # Videos
    ccids = list(set([resource["ccid"] for resource in resources if "ccid" in resource]))
    videos = list(db["video"].find(
        {"_id": {"$in": ccids}}, 
        projection=["name", "text"]))

    return dict(
        course=course,
        fields=fields,
        resources=resources,
        schools=schools,
        teachers=teachers,
        users=users,
        comments=comments,
        replies=replies,
        exercises=exercises,
        videos=videos,
    )

# %% [markdown]
# Test các thực thể truy vấn từ *course_id* C_676953

# %%
c_id = courses.loc[52, "id"]
sample = query(course_id=c_id, db=db)
print(c_id)
sample
# Out:
# C_676953
# {'course': {'_id': 'C_676953',
#   'prerequisites': 'C语言',
#   'about': '不仅仅是一门编程语言，汇编语言更是计算机系统软硬件的分界与桥梁，是理解整个计算机系统的有效起点，为学习后续的计算机系统课程打下基础。',
#   'school_id': 'S_1'},
#  'fields': ['计算机科学与技术'],
#  'resources': [{'_id': 'V_71673',
#    'ccid': 'BB2012EAC138EA979C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71674',
#    'ccid': 'DC4227387F8716419C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71675',
#    'ccid': '28B3AA48D6C4DCBA9C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71676',
#    'ccid': '55A4D3424F9E38539C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71677',
#    'ccid': 'B2DF7CB98A899C0E9C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71678',
#    'ccid': 'F1605AD9493E4C669C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71679',
#    'ccid': 'F583D1EE366342779C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71680',
#    'ccid': '93238A9393F49BCB9C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71681',
#    'ccid': 'D91EC6FCA01C69749C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71682',
#    'ccid': '52E38E401BA4E9569C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71683',
#    'ccid': '80C7CC1B874390E59C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71684',
#    'ccid': '77D8C7497773B4879C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'V_71685',
#    'ccid': 'B6875014B3182E179C33DC5901307461',
#    'title': '一、基础知识'},
#   {'_id': 'Ex_1067788', 'title': '一、基础知识'},
#   {'_id': 'V_71686',
#    'ccid': '57E6172D63C5793D9C33DC5901307461',
#    'title': '二、X86体系结构初步'},
#   {'_id': 'V_71687',
#    'ccid': 'EABB70C5881F858D9C33DC5901307461',
#    'title': '二、X86体系结构初步'},
#   {'_id': 'V_71688',
#    'ccid': '90E4F174D9933EF49C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71689',
#    'ccid': 'C043E9629D4443BA9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71690',
#    'ccid': 'D96C1DB23620E4339C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71691',
#    'ccid': 'BADA540A29F26F099C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71692',
#    'ccid': 'E0CE3D9E783002799C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71693',
#    'ccid': 'D7E88CCCECF7E44C9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71694',
#    'ccid': '3920E09BED9819859C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71695',
#    'ccid': '99289310CF978D089C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71696',
#    'ccid': '0BB8660EEA39D9129C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71697',
#    'ccid': 'F9053B0221C642FF9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71698',
#    'ccid': '03441403C4335FEB9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71699',
#    'ccid': 'D3097D0490F67F499C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71700',
#    'ccid': 'C2D81CED109272F09C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'Ex_1067790', 'title': '三、C与汇编语言'},
#   {'_id': 'V_71701',
#    'ccid': '729779BA1518AA7D9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71702',
#    'ccid': '00D2103C2C75894E9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71703',
#    'ccid': '8F6540CC45FFBF0B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71704',
#    'ccid': 'B21007DE273239A89C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71705',
#    'ccid': '0D760108788F4D0B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71706',
#    'ccid': '8D6545F9A7A9D5919C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71707',
#    'ccid': 'A182AFE3568886B39C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71708',
#    'ccid': 'B479F55E9C188D189C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71709',
#    'ccid': '8B450E01EC8293AD9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71710',
#    'ccid': 'C08E35A62B23A7439C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71711',
#    'ccid': '84D4F567E5D759039C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71712',
#    'ccid': 'B15B6D5A0E2165409C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71713',
#    'ccid': '57A5EBCF309977BE9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71714',
#    'ccid': '62596848F9D3A6B39C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71715',
#    'ccid': 'CB830E31A15AFB139C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71716',
#    'ccid': '973F618E8955C29D9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71717',
#    'ccid': 'CF58326927DB3EEF9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71718',
#    'ccid': '76AABC8383AA62339C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71719',
#    'ccid': 'B3E85AE92E0C71CE9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71720',
#    'ccid': '036129657D0E150E9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71721',
#    'ccid': '182B2E76A8909EAD9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71722',
#    'ccid': 'E67EDE9FB78918789C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71723',
#    'ccid': '0DA132AD4F7CCBCC9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71724',
#    'ccid': 'E06378F968494BA09C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71725',
#    'ccid': '58989B04461B46A79C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71726',
#    'ccid': 'B23F4692834CC02B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71727',
#    'ccid': 'B59FDC75B1E6B95B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71728',
#    'ccid': 'EC8115B5D889E0009C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71729',
#    'ccid': '273DA4DB2C3561A99C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71730',
#    'ccid': 'BD9BBB84743BEA4D9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71731',
#    'ccid': 'B9383FFAFFF157EE9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71732',
#    'ccid': '3AF8FC65575C7F969C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71733',
#    'ccid': 'F41455BB6060096B9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71734',
#    'ccid': '05FC849634F262859C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'Ex_1067791', 'title': '三、C与汇编语言'},
#   {'_id': 'V_71735',
#    'ccid': '1B9C2416C1BCFEFD9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71736',
#    'ccid': '6158DB949599CB659C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71737',
#    'ccid': 'B44888A4147311849C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71738',
#    'ccid': 'BBA18F49B187BBE89C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71739',
#    'ccid': '6D22ECECE415585C9C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'V_71740',
#    'ccid': 'D3C8AB3A3CA267B49C33DC5901307461',
#    'title': '三、C与汇编语言'},
#   {'_id': 'Ex_1067789', 'title': '三、C与汇编语言'},
#   {'_id': 'V_71741',
#    'ccid': '177A8173AA5561C79C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71742',
#    'ccid': '44F77BFAFBC7020B9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71743',
#    'ccid': '1B037196AE18DCC49C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71744',
#    'ccid': '0134B7CCFACD07B99C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71745',
#    'ccid': 'CEBED48A41E825A39C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'Ex_1067792', 'title': '四、\t汇编编程'},
#   {'_id': 'V_71746',
#    'ccid': '87D28DFBC6EF86E39C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71747',
#    'ccid': 'DB2EA5C5439229189C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71748',
#    'ccid': '399FA6CACF3112D89C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71749',
#    'ccid': '8F5151291F7F1B929C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71750',
#    'ccid': 'BDF912EA03D34EE79C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71751',
#    'ccid': 'E7122C05422418E29C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71752',
#    'ccid': 'E22283391062C5709C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71753',
#    'ccid': '085458758A0BCA499C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71754',
#    'ccid': 'BC13A7926CEB26B59C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71755',
#    'ccid': 'C469D0515A0664049C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71756',
#    'ccid': 'E5048843DB71A22B9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71757',
#    'ccid': 'A695096A4C335A8E9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71758',
#    'ccid': '7D51374FE56E98F59C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71759',
#    'ccid': 'D52F480E6D6F315E9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71760',
#    'ccid': '8C6E52E79815D1FC9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71761',
#    'ccid': 'FC709B4D20772A729C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71762',
#    'ccid': '24C72F80354A78309C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71763',
#    'ccid': '146774C6510F01A59C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71764',
#    'ccid': '5CEC1C1771A253909C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71765',
#    'ccid': 'B90AC00ADDF299229C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71766',
#    'ccid': '361B4E73FD34A45A9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71767',
#    'ccid': 'C576B4EC2FA119C99C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71768',
#    'ccid': 'FFD6B6E681974C739C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71769',
#    'ccid': 'C839096B2353111C9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71770',
#    'ccid': '00848A2EAF9DA5369C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71771',
#    'ccid': 'C81CC752272A1F239C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71772',
#    'ccid': '47D4987072FFF0B39C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71773',
#    'ccid': '03FE2B6C2434EAD79C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71774',
#    'ccid': '5835E41DD9A95BDB9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71775',
#    'ccid': '13DA74E75C6D3BD89C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'Ex_1067793', 'title': '四、\t汇编编程'},
#   {'_id': 'V_71776',
#    'ccid': '184BAA4A1E458C939C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71777',
#    'ccid': 'DE54A38371A2B96F9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71778',
#    'ccid': '3EFC69B9A092065D9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71779',
#    'ccid': '2144AA2746158B6A9C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71780',
#    'ccid': 'C652BE13F3F3BD429C33DC5901307461',
#    'title': '四、\t汇编编程'},
#   {'_id': 'V_71781',
#    'ccid': 'DEF75F9C28B43BB39C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71782',
#    'ccid': 'B823B3D0DD6C241D9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71783',
#    'ccid': '5DC8A08627BFE82E9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71784',
#    'ccid': '74507233A6717AD39C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71785',
#    'ccid': '0AD3C450811FF20C9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71786',
#    'ccid': '9F2E7CDC7D0FE07C9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71787',
#    'ccid': '12532056530A748C9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71788',
#    'ccid': 'BD9F3AC6A4DC3A559C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71789',
#    'ccid': '3029C26E425E758F9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71790',
#    'ccid': '7A1596ABFE156C449C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71791',
#    'ccid': '1B0AD22BDBB3F8899C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71792',
#    'ccid': 'E6FDB1DDA2388D059C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71793',
#    'ccid': 'BD5EEFD7B79A822E9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71794',
#    'ccid': '0D1E382A10284E259C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71795',
#    'ccid': '32FDF02CC0EDA40E9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'Ex_1067794', 'title': '五、MIPS汇编'},
#   {'_id': 'V_71796',
#    'ccid': '1A9E1A19E35C99B79C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71797',
#    'ccid': '4287F1B28B6D43B29C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71798',
#    'ccid': '7EE263DCBEDBCB5F9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71799',
#    'ccid': 'C12DBE1061E778CF9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71800',
#    'ccid': '990EDBFD0FDE3DE59C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71801',
#    'ccid': '0C6C4855D7EA4AF29C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71802',
#    'ccid': '33BCBF783119219D9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71803',
#    'ccid': 'CEFF530DD75222C69C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71804',
#    'ccid': 'E7840B18BE9CB29B9C33DC5901307461',
#    'title': '五、MIPS汇编'},
#   {'_id': 'V_71805',
#    'ccid': '90E88265B9CFFD6F9C33DC5901307461',
#    'title': '五、MIPS汇编'}],
#  'schools': [{'_id': 'S_117',
#    'name': '华北电力大学',
#    'about': '华北电力大学（North China Electric Power University）是教育部直属、由国家电网有限公司等12家特大型电力集团和中国电力企业联合会组成的理事会与教育部共建的全国重点大学，国家“世界一流学科建设高校”，国家“211工程”和“985工程优势学科创新平台”重点建设高校，上海合作组织大学能源学方向中方牵头院校，全球能源互联网大学联盟、北京高科大学联盟、CDIO工程教育联盟成员，中国电力高校联盟、电力行业卓越工程师培养校企联盟发起单位，入选国家“111计划”、教育部卓越工程师教育培养计划、国家建设高水平大学公派研究生项目、国家级新工科研究与实践项目、中国政府奖学金来华留学生接收院校、国家国际科技合作基地、国家创新人才培养示范基地。学校1958年创建于北京，原名北京电力学院，长期隶属于国家电力部门管理。1969年，学校迁至河北邯郸，1970年迁到保定，更名为河北电力学院。1978年经国务院批准为全国重点大学，同年更名为华北电力学院。1995年，华北电力学院与北京动力经济学院合并组建为华北电力大学。2003年3月，学校由原国家电力公司划转教育部管理，正式成为教育部直属高校。2005年10月，经教育部批准，学校校部由设在保定变更为设在北京，分设华北电力大学（保定）校区。据2020年9月学校官网显示，学校占地1600余亩，建筑面积100余万平方米，一校两地（北京、保定）三校区，两地实行实质性一体化管理；有教职工3千余人，全日制在校本科生2万余人，研究生1万余人。\n[1-8]',
#    'motto': '团结、勤奋、求实、创新'},
#   {'_id': 'S_67',
#    'name': '中华女子学院',
#    'motto': ''},
#   {'_id': 'S_1388',
#    'name': '集智学园',
#    'about': '集智学园是一个人工智能知识社区，主要面向技术类高管、高级工程师、科研人员，提供人工智能、机器学习、大数据、复杂系统等领域的系列讲解及定制化咨询服务。 集智AI学园是集智俱乐部孕育的创业项目之一。',
#    'motto': ''},
#   {'_id': 'S_1453',
#    'name': '贵州交通职业技术学院',
#    'about': '贵州交通职业技术学院是一所以交通为特色的理工类高职院校。创办于1958年，走过国家“示范校”、国家“优质校”发展历程后，2019年成功入选全国56所贵州目前唯一的“中国特色高水平高职学校建设单位”。',
#    'motto': '知行合一  德技双馨'},
#   {'_id': 'S_96',
#    'name': '首都师范大学',
#    'about': '首都师范大学（Capital Normal University），是国家“世界一流学科建设高校”，中华人民共和国教育部与北京市人民政府共建高校，教育部本科教学工作水平评估优秀学校，北京市属重点大学，京港大学联盟成员；入选国家建设高水平大学公派研究生项目、国家“特色重点学科项目”建设高校、教育部来华留学示范基地、教育部卓越教师培养计划、国家大学生创新性实验计划、中国政府奖学金来华留学生接收院校、乡村教师支持计划、首批高等学校科技成果转化和技术转移基地、北京市双培外培计划、北京华文教育基地；学科专业涵盖文、理、工、管、法、教育、外语、艺术等。\n[1]\xa0\n首都师范大学创建于1954年，原名北京师范学院，办学历史可追溯至1905年成立的通州师范；1960年后，华北人民大学、北京工农师范学院、北京艺术师范学院、北京师范专科学校等部分院系先后并入。1992年，北京师范学院分院并入，同年更名为首都师范大学。此后，北京联合大学外国语师范学院、北京第三师范学校、通州师范学校、北京市幼儿师范学校先后并入。\n[2]\xa0\n截至2019年3月，学校占地约88万平方米，建筑总面积约75.7万平方米，共有校本部、北一、北二、东一、东二、来广营、通州、良乡8个校区。馆藏各类图书文献1291.8万册（件）。学校下设31个院系和2个教研部。各类学生总数31559人，其中，全日制贯通培养生195人，专科生40人，本科生11245人，硕士研究生6691人，博士研究生851人，外国留学生2155人。有教职工2505人，专任教师1642名。\n[1]\xa0\n\n[3-4]',
#    'motto': ''},
#   {'_id': 'S_1',
#    'name': '清华大学',
#    'about': '简称“清华”，由中华人民共和国教育部直属，中央直管副部级建制，位列“211工程”、“985工程”、“世界一流大学和一流学科”，入选“基础学科拔尖学生培养试验计划”、“高等学校创新能力提升计划”、“高等学校学科创新引智计划”，为九校联盟、松联盟、中国大学校长联谊会、亚洲大学联盟、环太平洋大学联盟、清华—剑桥—MIT低碳大学联盟成员，被誉为“红色工程师的摇篮”。',
#    'motto': '自强不息,厚德载物'},
#   {'_id': 'S_266',
#    'name': '海南大学',
#    'about': '海南大学是于2007年8月由原华南热带农业大学与原海南大学合并组建而成的综合性重点大学，是教育部和海南省人民政府部省合建高校。',
#    'motto': '海纳百川 大道致远'},
#   {'_id': 'S_1402',
#    'name': '高雄医学大学',
#    'about': '高雄医学大学（Kaohsiung Medical University）源自1954年创校的“高雄医学院”，系由中国台湾医界菁英何礼栋、徐傍兴等教授及唐传宗、前高雄市长陈启川等无私捐献，与台湾第一位医学博士杜聪明教授共同创办，为台湾省内第一所私立医学院。1999年改名为“高雄医学大学”时，再成为台湾省第一所以“医学大学”命名的高等教育学校\n[1]\xa0\n。',
#    'motto': ''},
#   {'_id': 'S_76',
#    'name': '北京交通大学',
#    'about': '北京交通大学（Beijing Jiaotong University）是中华人民共和国教育部直属的全国重点大学，教育部、交通运输部、北京市人民政府、中国国家铁路集团有限公司共建高校，位列“211工程”、“985工程优势学科创新平台”、“世界一流学科建设高校”，入选高等学校创新能力提升计划、高等学校学科创新引智计划、卓越工程师教育培养计划、国家建设高水平大学公派研究生项目、新工科研究与实践项目、中国政府奖学金来华留学生接收院校、全国高校实践育人创新创业基地，是北京高科大学联盟、中俄交通大学联盟、中欧商校联盟、中欧工程教育平台、国际铁路联盟成员和中国人工智能教育联席会、“一带一路”铁路国际人才教育联盟理事单位。\n[1-2]\xa0\n学校是交通大学的三个源头之一，历史渊源可追溯到1896年，前身是清政府创办的北京铁路管理传习所，是中国第一所专门培养管理人才的高等学校，是中国近代铁路管理、电信教育的发祥地。1921年参与合并组建交通大学；1923年更名为北京交通大学；1970年恢复使用“北方交通大学”校名；2003年恢复使用“北京交通大学”校名。截至2020年3月，学校在北京建有东西两个校区，总面积近1000亩，建筑面积100余万平方米，另建有威海校区；设有15个学院，研究生院以及远程与继续教育学院；开设62个本科专业；有17个博士后科研流动站，21个一级学科博士点，33个一级学科硕士点；教职工3007人，其中专任教师1917人。学校以信息、管理为优势，交通科学与技术为特色，多学科协调发展。\n[2-3]',
#    'motto': ''},
#   {'_id': 'S_204',
#    'name': '沈阳建筑大学',
#    'about': '沈阳建筑大学（Shenyang Jianzhu University）是省部共建高等学校，属于辽宁省一流大学重点建设高校，入选国家“111计划”\n[1]\xa0\n，是国家百所中西部高校基础能力建设工程支持高校，国家卓越工程师教育培养计划实施高校，国家大学生创新创业训练计划实施高校。学校前身为1948年创建的中国人民解放军东北军区军工部工业专门学校（东北兵工专门学校），几经变迁，曾先后改建为东北建筑工程学校、沈阳建筑材料工业学院、辽宁省建设学院等。2004年5月正式定名为沈阳建筑大学。据2019年5月学校官网显示，学校主校区占地面积1500亩，建筑面积50万平方米；设有16个学院（教学部），47种专业，5个博士学位授权一级学科，16个硕士学位授权一级学科，15个硕士专业学位授权点，2个博士后科研流动站，11个省部级重点学科；拥有教职工1700余人，本科生11021人，博士、硕士研究生3026人，外国留学生858人。\n[2]',
#    'motto': '博学善建、厚德大成'},
#   {'_id': 'S_197',
#    'name': '浙江理工大学',
#    'about': '浙江理工大学（Zhejiang  Sci-Tech  University），简称“浙理工”，是一所以工为主，理、工、文、经、管、法、艺术、教育等多学科协调发展的省属重点建设大学。学校坐落于历史文化名城杭州市。入选教育部“卓越工程师教育培养计划“、中国政府奖学金来华留学生接收院校、全国高校实践育人创新创业基地、国家国际科技合作基地、国家级大学生创新创业训练计划、国家级新工科研究与实践项
养计划、国家大学生创新性实验计划、国家级大学生创新创业训练计划、国家建设高水平大学公派研究生项目、新工科研究与实践项目、中国政府奖学金来华留学生接收院校、全国深化创新创业教育改革示范高校、国家大学生文化素质教育基地、国家创新人才培养示范基地、国家国际科技合作基地、首批高等学校科技成果转化和技术转移基地、学位授权自主审核单位等，是中国高校行星科学联盟、中国人工智能教育联席会、大学通识教育联盟、粤港澳高校联盟、粤港澳大湾区物流与供应链创新联盟成员。1924年，孙中山先生亲手将广州地区多所高校整合创立国立广东大学。学校于1926年定名为国立中山大学。今日的中山大学，由1952年院系调整后分设的中山大学和中山医科大学于2001年10月合并而成。截至2019年9月，中山大学由广州校区、珠海校区、深圳校区三个校区、五个校园及十家附属医院组成；开设132个本科专业；有博士后科研流动站45个，一级学科博士点51个，一级学科硕士点59个，专业学位类别37种；有全日制学生53789人，其中本科生32160人，硕士研究生14463人，博士研究生7166人；专任教师4028人。',
#    'motto': ''},
#   {'_id': 'S_12',
#    'name': '西北工业大学',
#    'about': '西北工业大学（Northwestern Polytechnical University）简称“西工大”，位于陕西省会西安，直属中华人民共和国工业和信息化部，中央直管副部级建制，是中国唯一一所以同时发展航空、航天、航海（三航）工程教育和科学研究为特色的全国重点大学，位列国家“世界一流大学建设高校A类”、985工程、211工程；入选2011计划、111计划、卓越工程师教育培养计划、国家大学生创新性实验计划、新工科研究与实践项目、国家建设高水平大学公派研究生项目、中国政府奖学金来华留学生接收院校；卓越大学联盟、中俄工科大学联盟、中俄交通大学联盟、中英大学工程教育与研究联盟、“一带一路”航天创新联盟牵头成员，学位授权自主审核单位，欧盟QB50项目亚洲区唯一发起单位与亚洲区总协调单位。\n[1-2]\xa0\n1938年国立北洋工学院、国立北平大学工学院、国立东北大学工学院、私立焦作工学院在陕西汉中组建国立西北工学院；1946年迁至咸阳，1950年更名为西北工学院；1952年交通大学、浙江大学、南京大学的航空工程系在南京组建华东航空学院；1956年迁至西安，更名为西安航空学院；1957年，西北工学院与西安航空学院合并组建西北工业大学；1970年，原中国人民解放军军事工程学院航空工程系整体并入。\n[3]\xa0\n截至2019年12月，学校友谊、长安及江苏太仓三个校区占地面积7100多亩，下设23个学院、67个本科专业；拥有21个博士后流动站、21个一级学科博士点、34个一级学科硕士点；教职工4000余人，全职院士7人，在校生2.9万余人。\n[2]',
#    'motto': ''},
#   {'_id': 'S_122',
#    'name': '美国国家仪器公司',
#    'about': '在进行测试、控制和嵌入式设计应用的过程中，全球工程师和科学家设计、原型、发布系统的方式因NI而改变。NI开放的图形化编程软件和模块化硬件，每年帮助25,000多家公司的客户简化开发、提高效率，并极大地缩短了上市时间。无论是新一代测试系统，还是突破性地创建医疗设备，NI用户不断开发着造福大众的创新性技术。',
#    'motto': ''},
#   {'_id': 'S_362',
#    'name': '哈尔滨工业大学（深圳）',
#    'about': '哈尔滨工业大学（深圳）（Harbin Institute of Technology，Shenzhen）由哈工大与深圳市政府合作共建，是哈工大的一个校区，是中国九校联盟（C9）成员、国家“985工程”建设高校、世界一流大学建设高校（A类）。\n[1]\xa0\n哈尔滨工业大学（深圳）的前身是始建于2002年的哈尔滨工业大学深圳研究生院，2017年获批成立开展本科教育的哈尔滨工业大学（深圳）。2018年，中共哈尔滨工业大学（深圳）委员会成立。\n[1-2]\xa0\n截至2020年3月，学校设有10个学院、4个研究院；有8个国家一级重点学科；有全职教师400余人；有全日制在校生6200余人，其中本科生2600余人、硕士及博士研究生3500余人。\n[3]',
#    'motto': ''},
#   {'_id': 'S
#    'motto': ''},
#   {'_id': 'S_336',
#    'name': '西安电子科技大学',
#    'about': "西安电子科技大学（Xidian University）简称“西电”或“西军电”，是中央部属高校，1959年中央确定的首批20所全国重点大学，直属于教育部，由教育部与工业和信息化部、国家国防科技工业局、中国电子科技集团公司共建，位列国家“双一流”、“211工程”、“985工程优势学科创新平台”（特色985工程）、“2011计划”重点建设行列，是中国最早的2所国防工业重点军校之一（哈军工、西军电并称）和56所教育部批准设立的研究生院之一，''两电一邮''成员，先后入选首批5所科技部拨付专项经费的国家集成电路人才培养基地、首批6所教育部集成攻关大平台、首批7所世界一流网络安全学院、首批9所国家示范性微电子学院（理事长单位）、首批11所中国人工智能教育联席会常务理事单位、首批35所国家示范性软件学院。\n[1-10]\xa0\n学校前身是1931年诞生于江西瑞金的中央军委无线电学校，是毛泽东等老一辈革命家亲手创建的第一所工程技术学校， 历经中央军委工程学校、解放军通信工程学院、中国人民解放军军事电信工程学院等历史时期。截至2020年2月，学校南北两个校区总占地面积约270公顷，下设18个二级院部、63个本科专业；拥有9个博士后科研流动站，14个博士学位授权一级学科，26个硕士学位授权一级学科；专任教师2200余名，全职院士4人；全日制在校生3.5万多人，其中本科生2.2万多人、硕士生1万多人、博士生2260多人。\n[5]",
#    'motto': '厚德、求真、砺学、笃行'},
#   {'_id': 'S_455',
#    'name': '东北师范大学',
#    'about': '东北师范大学（Northeast Normal University），简称东北师大，位于北国春城-长春市，是中华人民共和国教育部直属高校，由教育部与吉林省人民政府共建综合性研究型全国重点大学；是世界一流学科建设高校、国家“211工程”和“985工程优势学科创新平台”重点建设高校，入选国家“111计划”、“国培计划”、卓越教师培养计划、国家建设高水平大学公派研究生项目、国务院侨办华文教育基地、教育部教育援外基地、国家大学生文化素质教育基地、国家大学生创新性实验计划、国家级大学生创新创业训练计划，是国家师范生免费教育和卓越教师培养计划试点高校、教育部“援疆学科建设计划”高校、中国-东盟教育培训中心承办高校、中国政府奖学金来华留学生接收院校。\n[1-5]\xa0\n东北师范大学于1946年建校，原名东北大学，是中国共产党在东北地区创建的第一所综合性大学。1950年根据国家教育事业发展的需要，易名东北师范大学。1953年，学校开始招收和培养研究生。1958年划归吉林省管理，更名为吉林师范大学。1980年重新划归教育部，复名为东北师范大学。2019年4月学校官网信息显示，东北师范大学有自由校区和净月校区，占地面积约2512.16亩；全日制在校学生28024人；专任教师1557人；设有23个学院（部），78个本科专业，38个硕士学位授权一级学科，17个硕士专业学位授权点，22个博士学位授权一级学科，2个博士专业学位授权点，20个博士后科研流动站，5个国家重点学科，6个“双一流”建设学科。\n[6]',
#    'motto': ''},
#   {'_id': 'S_173',
#    'name': '桂林理工大学',
# ...
#     '一个外部',
#     '一个内部的碎片化',
#     '所以说我们要做一个内存分配程序的话呢',
#     '这两块问题是要好好解决的',
#     '你的效率本身很多情况下',
#     '就取决于这两个问题',
#     '那么在这种情况下呢',
#     '我们再往下讲',
#     '我们要实现内存管理功能',
#     '实际上就是堆的管理功能',
#     '要实现两个函数',
#     '一个就是分配',
#     '一个就是释放',
#     '分配函数叫allocation',
#     '那么怎么做法呢',
#     '首先我们可以想想',
#     '肯定是在堆里面',
#     '要形成一个类似于链表一样的结构',
#     '链表一样的结构',
#     '我们要分配的时候呢',
#     '肯定是从链表头开始查',
#     '一个一个往下查',
#     '那最笨的办法',
#     '就是一个一个往下查',
#     '查到哪一个块是空闲的',
#     '同时它的长度又足够',
#     '我们就把它分出来',
#     '那么释放的话呢',
#     '那就好办一点',
#     '就是我们只要相应的标志块',
#     '标志位可用就可以了',
#     '所以呢 就这么做',
#     '在这个时候呢',
#     '我们从堆当前system brk起始地址开始',
#     '遍历每个内存块',
#     '如果某一个内存块标记位是可用的 ',
#     '同时它是free的',
#     '没有被分配掉的',
#     '而且其尺寸足够',
#     '就将其标为不可用',
#     '并返回其数据块的地址结束',
#     '当然这算法很简单很粗糙',
#     '否则去遍历一直找到为止',
#     '如果一个都找不着',
#     '那么就能过系统调用增长',
#     '你这个堆的上限',
#     '因为你不够用都不够用',
#     '那么就把堆的上限往上涨一涨',
#     '你要多少就涨多少',
#     '然后再把这一块分给你就行了',
#     '那如果释放的话呢',
#     '就是把相应的标志位标志为可用',
#     '比方说这个样子',
#     '一个块的长度一个块的单元是这个样子',
#     '这是一个块的单元',
#     '你真正分配出来的数据是playload',
#     '真正人家能用的数据块在这',
#     '你前面应该有个头',
#     '头里面有两个元数据',
#     '是管理用的',
#     '一个是标志它当前',
#     '是不是已经被分配出去了',
#     '再一个标识你的块的长度是多少',
#     '你在块长度之后呢',
#     '相当于一个指针式了',
#     '你可以找到下一块的地址了',
#     '这里都有了']},
#   {'_id': '4287F1B28B6D43B29C33DC5901307461',
#    'name': '异常处理向量',
#    'text': ['针对异常进行处理有个概念',
#     '叫做异常处理向量',
#     '什么意思 ',
#     '就是说异常分不同类型',
#     '不同类型都有一个号',
#     '所以它的系统里就维护一个',
#     '异常的处理向量表',
#     '你这个号',
#     '对应表里的一项',
#     '这一项的地址',
#     '就是要处理这个异常的代码的入口的地址 ',
#     '就是向量处理方式',
#     '注意啊',
#     '向量处理方式并不是说所有的处理器',
#     '都有这种方式',
#     '因为这种方式想想看',
#     '如果不同的异常号',
#     '直接可以通过查表的方式',
#     '马上跳到它所对应的处理入口',
#     '这种方法是比较快的',
#     '比较实时的',
#     '但是有一些处理器',
#     '比如说在mips课上讲的',
#     '4kc 蓝本讲的',
#     '4kc处理器就没有这种方式',
#     '它的异常入口地址非常少',
#     '就那么几个',
#     '完了进去之后呢通过软件访问',
#     '来判断当前到底哪个异常',
#     '然后再跳到不同的入口',
#     '这个就慢了',
#     '所以它实时性不是太好',
#     '处理向量就是实时性比较好的一种方式',
#     '所以不能一概而论',
#     '实际情况不一定一样',
#     '这个里面提到过了',
#     '每类异常都有编号',
#     '对应一个入口地址',
#     '这样如果快的话',
#     '就可以直接跳过去',
#     '但是有些处理器',
#     'mips处理器早期没有这种方式',
#     '它从4ke才开始引入',
#     '我们讲到4kc里面还没有',
#     '但是这不是什么本质问题',
#     '再者跟异常相关的非常重要的概念',
#     '叫做精确异常处理',
#     '什么是精确异常处理',
#     '就是在处理异常的时候',
#     '产生异常指令之前的指令',
#     '都应执行完毕',
#     '该指令之后包括该指令本身的指令',
#     '都不处理',
#     '比如你调用了一个system  call',
#     '这条相应的指令',
#     'system call这条指令之前所有的代码',
#     '应该处理完毕',
#     '这条指令之后应该不处理',
#     '当然system本身处理过程 ',
#     '当然system  call有点特殊了',
#     '因为你对异常处理的过程本身',
#     '实际上也可以看作是',
#     'system call指令处理的本身',
#     '所以回来之后直接走到下一条指令去了',
#     '但原则上就是这个样子',
#     '哪个地方发生异常了',
#     '之前的指令处理完毕',
#     '引起异常以及这条指令本身',
#     '以及它之后的指令通常不做处理',
#     '看它恢复情况该怎么做处理',
#     '那么这种情况下话呢',
#     '需要精确的记录异常的位置',
#     '到底是由哪条指令触发的',
#     '完了就看情况呢',
#     '到底是要它重新执行',
#     '还是到下一条执行',
#     '但有可能是Aborts掉',
#     '再一来针对mips 而言',
#     '还一条稍微特殊的一个情况是什么',
#     '就是我们已经讲过了',
#     'branch delay slot ',
#     '什么意思 ',
#     '如果你是在branch delay slot',
#     '就是说在你这个跳转指令',
#     '条件跳转指令slot里头触发的异常',
#     '那么这种情况下如果你要返回的话',
#     '我们记得因为branch delay slot',
#     '里头的指令',
#     '的一个特性是什么',
#     '就是不管你的branch指令跳还是不跳',
#     '它是一定要执行的',
#     '那么这样的话呢',
#     '如果是这条指令触发了异常',
#     '异常返回的话',
#     '也要返回到那条相关的branch指令',
#     '或者是jump指令',
#     '而不能返回到它本身',
#     '所以这是一个异常情况',
#     '这是一个特殊情况',
#     '大家要注意',
#     'mips里面特有的',
#     '接下去就简单了',
#     '需要取消后续指令',
#     '需要正确的恢复执行',
#     '比方说我们在这个段',
#     '第二条指令里面的alu段发生了异常',
#     '这种情况下话呢一般来说',
#     '指令1要执行完毕',
#     '指令2就要cancel掉了',
#     '指令3指令4就更不用说了',
#     '精确异常',
#     '同时你要根据指令的异常',
#     '不同的处理的结果 ',
#     '来看看它是应该要返回指令2',
#     '还是什么精确的情况 ',
#     'mips32情况下一些异常指令的类型',
#     '我就不详细说',
#     '大家看一看',
#     '有的是reset',
#     '调试相关的',
#     '有的不可屏蔽中断的冲突 ',
#     '比方说断电什么的',
#     '还有machine check ',
#     '我们就不去说它了',
#     '这个大家用的时候可能来谈到',
#     '为什么讲这个呢',
#     '大家想想看',
#     '因为清华计算机系的学生',
#     '你们应该有相当一部分应该在',
#     '后续课程里面',
#     '讲组成原理的话',
#     '你们会去做一个mips的处理器',
#     '上面要跑os以及相关的compiler',
#     '就是说你要跑os的话呢',
#     '异常的支持是必不可少的',
#     '所以说你应该先有这个概念',
#     '以便于你后续做大实验的时候',
#     '有这些基础的知识 ',
#     '我们以前讲过这个事',
#     '当然有各种各样的异常的类型',
#     '但一般来说',
#     '并不需要都支特',
#     '太多了',
#     '一般来说syscall肯定是要支持的',
#     '还有相关的 ',
#     '如果你要支持虚存的话',
#     '应该来说必须要支持虚存',
#     '跟tlb相关的',
#     '我们回头会讲',
#     '这应该也是要支持的',
#     '当然还有一些许多的其他异常的类型',
#     '大家可以看一看',
#     '回去查一查',
#     '比方说ri这条指令 这个异常',
#     'ri  Reserved instructions',
#     '执行保留指令',
#     '这个指令可能会有一定的用处',
#     '比方说',
#     '如果你们想对对某个指令进行扩展的话',
#     '多个指令进行扩展',
#     '虽然有些可能会有不同的扩展方式',
#     '因为据我所知',
#     '咱们这个实验里头',
#     '让大家实现最基本的一些指令就可以了',
#     '大概5 6 十来条这样子',
#     '但比方说如果你想做一条浮点指令',
#     '做进去的话',
#     '怎么办呢',
#     '浮点指令',
#     '当然浮点处理器本身不太好做',
#     '硬件上来讲',
#     '它有种方式是什么呢',
#     '可以说把这条浮点指令',
#     '通过一个异常方式',
#     '就是说一旦在你流水线里面',
#     '发现了一条浮点指令',
#     '你可以把这条浮点指令',
#     '做为一条保留指令',
#     '触发一条保留指令的异常',
#     '然后在你异常的handle里头',
#     '通过软件方式',
#     '把这浮点指令的功能给它实现一遍',
#     '就是用整型去',
#     '模拟一个浮点的算法 ',
#     '这也是一种扩展方式',
#     '就跟大家这么一说',
#     '下面有一些比如说tlb相关的',
#     '这个可能有用',
#     '因为你们回头如果支持os的话',
#     '要支持实虚存的相关的对应',
#     'tlb 的异常是一定要处理的']},
#   {'_id': '44F77BFAFBC7020B9C33DC5901307461',
#    'name': '汇编指示-1',
#    'text': ['那完了我们再细化了说说看',
#     '有些东西就是',
#     '我们以前再讲C跟汇编对应的时候',
#     '有些东西还没有讲到',
#     '这里面咱们再重申一下',
#     '汇编代码当中',
#     '以点开头的行是汇编的指示',
#     '叫Directives',
#     '如点file 点def  点text等',
#     '用以指导汇编器如何进行汇编',
#     '那其中一些呢',
#     '比如说 点file  点def',
#     '均用于这种调试',
#     '所以我们可以将其忽略',
#     '不用去理它',
#     '跟编程序没有什么关系',
#     '比方说 点def里面',
#     '第一个main什么的',
#     '我们就不去说它了',
#     '有兴趣可以查一些参考书',
#     '那么跟我们相关的是什么呢',
#     '看看这个',
#     '以冒号结尾的字符串',
#     '就是说_mian冒号',
#     '是用于表示它后面的变量',
#     '或者说数据',
#     '或者说函数的地址的符号',
#     '这个我们稍微强调一下',
#     '比如说我们里面提到的那个main函数',
#     '刚才说的main函数',
#     '它的入口地址就是main',
#     '包括那个lc0',
#     '用于指示这个要输出的字符串的地址',
#     '我们知道就是说',
#     '在C程序转换成汇编的时候',
#     '这个编译的过程',
#     '比如说汇编转换成一个目标程序',
#     '这个过程的时候',
#     '其实呢 这些字符串也好',
#     '字符串的地址也好',
#     '或者说相关的函数地址也好',
#     '这些都是不知道的',
#     '为什么不知道呢',
#     '大家知道',
#     '往往我们现在写程序的话',
#     '经常有多个目标程序',
#     '要链接在一起之后',
#     '才能形成最终的执行文件',
#     '那么每个程序呢',
#     '实际上都有自己的代码部分',
#     '或者说某个函数',
#     '然后都有自己的数据的声明的部分',
#     '那这些代码部分',
#     '数据声明部分',
#     '要把大家集合到一起之后',
#     '形成一个带大的一个代码段',
#     '或者说大的一个数据段',
#     '那么在这个前提下',
#     '才有可能大家知道就是',
#     '我这块函数',
#     '或者说我的这个数据',
#     '要放到那个地址',
#     '或者说放到哪个相应的位置才知道',
#     '所以在C到汇编的时候',
#     '包括汇编到你的目标程序的时候',
#     '这个地址一般来说是不知道的',
#     '但不知道呢',
#     '你要用它',
#     '你要调一个函数',
#     '或者说你要在',
#     '包括刚才puts里面的例子',
#     '你要去引用一个字符串的地址',
#     '哪咋办呢',
#     '就拿一个符号来表示它',
#     '这个符号一般来说表示一个常量',
#     '就是说这个常数',
#     '地址我们还不知道',
#     '我后面 什么时候才知道呢',
#     '到程序链接的时候才知道',
#     '链接我们会在下一节课',
#     '作为补充内容来讲',
#     '就说这个还不知道',
#     '不知道地址',
#     '我们在程序里面',
#     '我们怎么表示呢',
#     '就用一个符号来表示',
#     '刨去这些之外',
#     '基本上都是汇编指令了',
#     '那么这里面咱们就举一个例子',
#     '比方说 点globl _main',
#     '这是一个符号',
#     '它这个就是指示汇编器',
#     '这个符号main是全局的',
#     'globl是一个全局的一个函数',
#     '说白了',
#     '这样呢',
#     '同一个程序的其他模块可以引用它',
#     '什么意思呢',
#     '就是说 你写的点C',
#     '里面 声明一个globle的函数',
#     '那么另外一个点C呢',
#     '就可以去使用它',
#     '去call它',
#     '这说明是全局可见的',
#     '这个同一程序内部全局可见的',
#     '而lc0呢',
#     '前面没有这样的声明',
#     '就是说那个hello world字符串',
#     '这个就是局部可见的',
#     '不是全局可见的',
#     '外部模块不能够去使用它',
#     '就是这个意思',
#     '点globl就是这个意思 全局的',
#     '后面就指明你这个符号',
#     '你这符号是什么性质',
#     '就用它来指好',
#     '而这个符号呢',
#     '实际上就表示地址',
#     '是个函数的入口地址',
#     '或者说函数地址吧',
#     '或者说正文地址',
#     '或者说就是一个后面声明的数据地址']},
#   {'_id': '47D4987072FFF0B39C33DC5901307461',
#    'name': '程序链接-8',
#    'text': ['下面再讲讲我们说的swap',
#     '就这个函数',
#     '它里面的这些重定位信息',
#     '这个就麻烦一点了',
#     '首先说swap这个模块代码段的',
#     '重定位里面的信息是什么',
#     '首先我们看一眼啊',
#     '这个内容比较多',
#     '这个就我们还是解释这些红字',
#     '或黄字的部分',
#     '因为我们可以看到这个C代码里面',
#     '里面这一堆都是',
#     '比方说你它的位置是什么',
#     'bufp1的位置是什么',
#     '大家都不知道了',
#     '所以这么看一看  看看右侧',
#     '实际上这个解释方式跟刚才是一样的',
#     '这里面一行2：R_386_32 bufp0',
#     '说明什么呢',
#     '就说明从swap它所在的这个代码段',
#     'offset  2开始',
#     '0 1 15后面就是',
#     '后面00就是2的位置嘛',
#     '就是这4个红色的0',
#     '就表示我从这个地方要填入',
#     '一个32位的一个地址',
#     '这个地址的值是多少呢',
#     '就bufp0',
#     ' 实际上就是这个变量所在的位置',
#     '也就是说这个标号它所代表的位置',
#     '我一旦获得之后呢',
#     '我要把这个32位的地址',
#     '填到这边offset为2开始的',
#     '连续的4个byte里面去',
#     '就是这个意思',
#     '下面是类似',
#     '你看我这7：R_386_32',
#     '它的标号对应是buffer',
#     '也就是说我获得这buffer地址之后',
#     '我要对应的把这个位置',
#     '填到offset  7开始的连续的',
#     '4个字节里面去',
#     '但这里面有意思',
#     '你看前面那个是00 00 00 00 ',
#     '这边是04 00 00 00这个04是干吗的',
#     '大家想想看',
#     '其实这个代码看起来有点',
#     '不是特别好理解',
#     '因为你跟左侧swap.c比较复杂',
#     '不一定能一一对得上',
#     '实际上这个04是什么意思',
#     '大家想想看',
#     '因为buf本身',
#     '它代表了一个全局变量所在的地址',
#     '但是呢',
#     '我的左侧代码',
#     '大家可以看',
#     '有的是取决于bufp 1的地址',
#     'bufp 1的地址',
#     'bufp 1和buf 或者说buf',
#     '这个起始地址差多少 ',
#     '其实差个4',
#     '那这个4怎么表示呢',
#     '它就把4搁到这了',
#     '就是04 00 00 00',
#     '相当于就是说 ',
#     '我要把这buf地址拿过来之后呢',
#     '再加上我原来这个域里头',
#     '填了一个4就是我最终所需要的地址',
#     '一会儿我们再解释',
#     '我们把这两段代码对应起来后',
#     '你就会看得明白了',
#     '完了再往后的话呢也是类似',
#     '类似什么呢',
#     '比方说咱们这个黄的',
#     '从10位置开始你看这是e吗 f',
#     '第一个黄色的两个0就是10的位置开始',
#     '这10位置开始呢',
#     '我们在这里面要填的一个地址',
#     '就是bss的起始地址',
#     'bss里面填个什么数',
#     '就是填了int *的bufp1的地址',
#     '就把它的这个地址呢',
#     '一旦解析完成了之后',
#     '就填到10位置开始的连续4个byte里面去 ',
#     '那么红色的话呢也是类似',
#     '就跟上面类似',
#     '还是就是说因为它起始地址是14么',
#     '就把buf这个地址填到这',
#     '但是要加4因为它原来位置有个4在里头',
#     '其实可以想像就是填的是哪个位置',
#     '我们可以在这边对照出来',
#     '我们可以想想看',
#     '再往后的话呢也是类似',
#     '我在这个地方呢',
#     '也是要在1f所开始的这个位置',
#     '就是89 0d 04这边开始的地方',
#     '我要填入这个buffer的这个地址',
#     'buffer地址填的实际是要填的地址加4',
#     '因为它这里面原来是04 00 00 00',
#     '相当于你新填的这个数',
#     '要跟原来的地址加上去',
#     '其实我们可以想想',
#     '它这个里面还举了一个什么例子',
#     '还举了buf1 buf里面01',
#     '这个相对第二个元素的地址',
#     '给它填到这里面去了',
#     '大家可以这么理解',
#     '但这个不是特别直观',
#     '因为这里留了许多空泡',
#     '所以这些它这个代码',
#     '还是不好跟swap.c对上',
#     '我们一会儿会讲',
#     '填完之后就清楚了',
#     '当然还有一个重定位信息',
#     '就是关于swap data段里面',
#     '那么data段里面看到',
#     '它里面声明了一个什么',
#     '就是buf p0',
#     '这比较麻烦',
#     '你看bufp0它本身的位置我们就不晓得',
#     '填哪不晓得',
#     '装配完了才知道',
#     '因为链接完了之后才知道',
#     '另外呢',
#     '它里面所知道的初始化的值呢',
#     '是buf 0第一个元素的起始位置',
#     '实际也是buffer数组起始的位置',
#     '那么是什么位置呢',
#     '那当然我们也不知道',
#     '那不知道怎么办呢',
#     '这边还是以此类推',
#     '填一个数0',
#     '我这边要把buffer的这个地址',
#     '填到0位置开始的连续4个byte里面去',
#     '也就是说因为你看这个',
#     '相当于在你程序最后链接生成之后',
#     'buf p0要被初始化的一个全局变量',
#     '所以在你执行之前',
#     '你的这个数值必须被填上',
#     '所以呢应该要linking 来解决这个问题']},
#   {'_id': '52E38E401BA4E9569C33DC5901307461',
#    'name': '浮点数的规格化与非规格化表示',
#    'text': ['那么接下来就讲  我们大概知道浮点数在',
#     '计算机内部要分成这个三个域来表示',
#     '那么具体呢怎么个表示法',
#     '就浮点数的类型 那分成三个方面来讲',
#     '就是还是我们根据这个IEEE754的标准',
#     '它把浮点数呢分成三个类型',
#     '规格化的 非规格化的',
#     '和其他一些特殊的值',
#     '我们分头来讲解一下',
#     '首先说什么是规格化的浮点数',
#     '大家看一下 满足条件是什么呢',
#     '就我们说那个exp那个域啊',
#     '既不能是全0也不能是全1',
#     '当然首先我们要知道就是exp的这个域',
#     '是怎么得到的 因为刚才讲过啦 就是',
#     '一个实数的浮点数表示呢 ',
#     '分成三个域 按照负1的s次方',
#     '乘上2的e次方再乘上M这种方式来表示',
#     '完了这三个域呢以0101串的形式',
#     '存到存储单元里面去',
#     '但这里头呢除了这个s之外',
#     '另外两个域都做了一个简单的转换',
#     '就是 你存到硬件里面的那exp',
#     'exp 比方说啊 拿它作为例子 ',
#     '这个exp并不完全就等于那个e',
#     '不等于那个e 那怎么个表示方式呢',
#     '就是 真实的阶码值啊',
#     '需要减去一个偏置量',
#     '那么这个实际上我们好理解',
#     '因为 我们呢把这个数字',
#     '存到计算机内部的时候呢 是个0101串',
#     '那么这个01串呢可以',
#     '可以表示一个无符号的数值',
#     '完了这个无符号的数值呢',
#     '又要减去一个偏置量',
#     '这个才是它最终真正表达的那个e',
#     '就那个阶码的那个值 这个很重要',
#     '因为我们说过呢 ',
#     '因为把exp看成一个无符号数值的话呢',
#     '那它就是一个大于等于0的一个数',
#     '但是e这个值本身肯定是有正有负嘛',
#     '它是个多少次方嘛 肯定有正有负',
#     '所以要减去一个偏置量',
#     '那偏置量大概怎么去算呢',
#     '它是2的e减1次方 减1',
#     'e嘛就等于这个exp的位数',
#     '那么反过来讲的话呢',
#     '单精度数那么在这种情况下的话就是127',
#     '那double的话呢就是1023',
#     '这个我们要稍微记一下 就是说',
#     '在咱们这门课里头',
#     '要真正要记的内容非常非常少',
#     '但浮点数里面关于',
#     '这种不同类型浮点数的规格的定义',
#     '包括这类东西记一记 第二呢就frac域 ',
#     'frac域呢就针对我们刚才说的那个',
#     '负1的s次方乘上2的e次方',
#     '再乘上M 就对应那个M',
#     '那M呢是一开始得多少呢',
#     '就是应该是1点xxx这种形式',
#     '我们说过它有个',
#     '表示1点0到2点0的一个数嘛',
#     '左侧是一个闭区间',
#     '那为了提升表示的效率',
#     '具体表示的时候呢',
#     '只是取这个M的 这个小数点右侧的部分',
#     '所以呢 它最小就表示 全0',
#     '那实际上它就指1点0 那么最大呢就是全1',
#     '那么全1这个数呢实际上真实的数值呢',
#     '就比2.0要小那么一点点',
#     '因为它是个开区间嘛 ',
#     '这个呢有的时候稍微要记一下',
#     '我们刚才说过了 记的东西不多',
#     '差不多就这些啦',
#     '浮点数里头就是这种',
#     '不同的表示的方式的规格 不同的规格',
#     '这个要记一下',
#     '那么这里面就给了一个简单的例子',
#     '一个浮点数F等于15213',
#     '首先非常简单的 ',
#     '我们就把它的十进制的表示呢',
#     '转换成一个二进制的串',
#     '我们要把它规格化一下表示',
#     '有个前导1 就是1点xxx的这种形式',
#     '那么相当于就是我们把小数点就是往',
#     '左侧挪了 挪成1点xxx的这种形式',
#     '当然最后呢要乘上2的13次方',
#     '再把这个值得掰回来 值的大小不能变',
#     '所以这样一来的话呢 ',
#     '我们就把它表示成了',
#     '负1的s次方乘上1点xxx的相当于就是M',
#     '再乘上2的整数次幂 ',
#     '这很简单 当然这个因为是正数嘛',
#     '这个s当然肯定就是0啦 这个毫无疑问',
#     '那么它的尾数呢 目前我们知道它是',
#     '1点111 相当于它有效数位就这些',
#     '我们刚才说过啦',
#     '它要是把它表示成为frac 就是表示成为',
#     '真正存到',
#     '这个存储单元里面这个数据的话呢',
#     '小数点左侧这个数是可以去掉的 ',
#     '因为它是规格化的浮点数嘛',
#     '所以表示成1101101101101 这个形式 ',
#     '当然后面还得补齐啦',
#     '因为它一共有23位嘛 要把它补齐',
#     '我们还记得 浮点数 这个floating point',
#     '如果是单精度的话呢 就是 32位',
#     '应该是1符号位 23位的这个有效数据',
#     '再加上8位的多少次方 这个表示',
#     '那接下来就是这个阶码了',
#     '那么它的真实数据是13',
#     '那么我们要把它表示成为',
#     '内部硬件表示的那个exp这个域的话呢',
#     '应该加上它的一个偏置量',
#     '2的e减1次方 减1 就127',
#     '所以算出来是140 然后呢我们就集大成',
#     '把下面的这一块整个的给它结合起来',
#     '所以我们可以非常清楚的知道',
#     '最终的这个二进制的表示呢就是什么呢',
#     '就是 第一位就是0 0就是它的符号位',
#     '然后呢是阶码 就是1000 1100',
#     '再往后呢 就是它的尾数',
#     '尾数呢因为前导1去掉了',
#     '所以后面那一串 这个呢我们应该都会',
#     '看起来很简单就讲了一个例子在这儿',
#     '接下来呢我们再讲讲这个',
#     '非规格化的浮点数 刚才是规格化的',
#     '现在是非规格化的 那么这种情况下呢',
#     '非规格化浮点数要满足什么条件呢',
#     '就是exp等于全0 刚才说啦',
#     '既不能全0也不能全1 叫规格化浮点数',
#     '那个非规格化浮点数呢就是exp要等于全0',
#     '那么其他域的取值呢 E等于负Bias加1',
#     '就是偏置量前面加个负号',
#     '再加上1或者说1减去这个偏置量',
#     'M呢就等于0点xxx的这种形式',
#     '实际上大家这个可以回想一下',
#     '就是浮点数的表示',
#     '就跟我们说它是floating point',
#     '这个点能浮动 那它的实质是什么呢',
#     '比方说这个实数或者整数',
#     '要表示成1点xxx的这种形式',
#     '然后乘上2的多少次方',
#     '但是如果你说这个2的多少次方',
#     '如果这个数特别特别小的话',
#     '小到什么程度呢 就小到就是说',
#     '你把它表示成为1点xxx这种形式',
#     '然后再乘上2的多少次幂 多少次方',
#     '就是这个地方太小了 会假设怎么着 ',
#     '比如说你的2的负多少多少次都不够用啦',
#     '那这种情况下怎么办呢',
#     '那相当于就是说你这个e就不能变啦',
#     '因为e已经到头啦 最小啦',
#     '那这时候就怎么再往小了表示',
#     '那就是说你这种情况下只能就是说',
#     '你小数点继续的往左边移',
#     '就是继续往左边大家可以想象',
#     '那再往左边移的话呢',
#     '这个数的绝对值肯定是变小了',
#     '绝对值肯定变小了',
#     '同时呢 它的数的精度是降低了',
#     '它的精度是降低了 在这种情况下',
#     '因为它相当于把有效数位挪出去了嘛',
#     '所以呢它这个M就0打头啦',
#     '就变成这个意思',
#     '那么具体示例大概是这样子',
#     '如果exp是全0 frac亦是全0',
#     '那么就表示0了 在浮点数表示里面啊',
#     '0有正0和负0 ',
#     '这个跟我们说整数的时候不一样',
#     '就是说这个带符号整数的时候',
#     '带符号整数0就一个表示嘛',
#     '就唯一的一个表示',
#     '100000反倒是最小的那个数',
#     '就是最小的那个数',
#     '那么这里面呢就是有正0和负0',
#     '当然正0和负0实际上就差了一个符号位',
#     '它们的值当然是相等啦 这个毫无疑问',
#     '那么如果说exp如果是全0 而frac不是全0',
#     '它就表示“非常接近”于0的浮点数',
#     '就是说你的幂次的绝对值非常非常的小啦',
#     '那frac域你怎么再去表示这个数',
#     '那只能就是说丧失这个精度',
#     '把有效数位移出去',
#     '所以我们这边有一概念叫做什么',
#     '叫做逐步丧失精度',
#     '这跟我们上节课讲的那个整型不一样',
#     '整型的话 比方说你这个',
#     '两个无符号整数相加 ',
#     '两个比较大的数相加',
#     '一加起来一旦溢出它的 一旦产生溢出',
#     '就是超过了你能精确表示的上限',
#     '那个数一下就变小了',
#     '那么两个带符号的数 如果说比方说相加',
#     '就两个比较正的带符号数相加',
#     '出来值比较大的话就变成负的啦',
#     '相反两个负的相加可能变成正的',
#     '所以它这种溢出是突然的',
#     '一下这个值就好像就翻转下来这种感觉',
#     '实际上 这边就不会 它就逐步的',
#     '通过丧失精度的方式',
#     '实际上它是已经没法精确表达了',
#     '但是我还是能够表示 就降低精度嘛',
#     '实际上就是这个意思',
#     '再就讲第三种 一些特殊的值',
#     '这个比较有意思 就是说',
#     '如果exp等于全1 且frac等于全0',
#     '就表示无穷',
#     '就是正无穷负无穷数学上有这个概念嘛',
#     '所以说作为这个IEEE754标准啊',
#     '它在这方面还是这个考虑得比较完备的',
#     '就是正无穷负无穷我都给你表示出来了',
#     '这个当然是有意义的啦 ',
#     '就是你数值溢出了就比方说 这些式子',
#     '你在数学上面就表示无穷嘛',
#     '它出来这个值 ',
#     '所以在这里面呢也可以表示',
#     '那么第二种是什么呢',
#     '就是exp等于全1 frac不等于0',
#     '这就表示不是数的数',
#     '就是说 你计算机之间的数',
#     '在数学上面没法表达',
#     '就是你给负1开个根号',
#     '当然你说这是虚数 ',
#     '当然这里面没有这么一说啊',
#     '它们只是在实数范围之内',
#     '所以这里面指的就是说是这个',
#     '不是数的数 它这里也能够这种表示',
#     '所以总的来说呢这个IEEE754的标准',
#     '对这种数值的表示还是比较完备的',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '',
#     '']}]}

# %% [markdown]
# Thống kê số lượng các thực thể số nhiều của course C_676953

# %%
for k, v in sample.items():
    if isinstance(v, list):
        print(f"{len(v)} {k}")
# Out:
# 1 fields
# 140 resources
# 422 schools
# 2 teachers
# 41 users
# 0 comments
# 0 replies
# 0 exercises
# 40 videos

# %% [markdown]
# ### Encode thông tin của các thực thể
#
# - Dữ liệu dạng text: Sử dụng mô hình XLM-R, và lấy vector đặc trưng đại diện cho sentence embedding.
# - Dữ liệu category: Mã hóa one-hot.
#
# **Ý tưởng:** 1 thực thể bao gồm nhiều property sẽ được biểu diễn bằng cách nối vector embedding của mỗi property với nhau.
#
# **Ví dụ:**
#
# Course = (*about*, *prerequisites*)
#
# $\rightarrow$ Encoding(Course) = [Encoding(*about*), Encoding(*prerequisites*)]

# %%
print("Raw course:")
print(sample["course"])

print("Encoded course:")
print(encode_course(sample["course"]))
# Out:
# Raw course:
# {'_id': 'C_676953', 'prerequisites': 'C语言', 'about': '不仅仅是一门编程语言，汇编语言更是计算机系统软硬件的分界与桥梁，是理解整个计算机系统的有效起点，为学习后续的计算机系统课程打下基础。', 'school_id': 'S_1'}
# Encoded course:
# tensor([[-0.0867,  0.0782,  0.0976,  ..., -0.2662, -0.0538, -0.0740]])

# %% [markdown]
# ### Hàm số chuyển đổi các thực thể của course cho phù hợp với API của `torch_geometric`

# %%
import torch
from torch_geometric.data import HeteroData
import torch_geometric.transforms as T

def to_hetero_data(sample: dict):
    data = HeteroData()
    # Xây dựng encoding cho các thực thể
    data["course"].x = encode_course(sample["course"])
    data["field"].x = encode_fields(sample["fields"])
    data["resource"].x = encode_resources(sample["resources"])
    data["school"].x = encode_schools(sample["schools"])
    data["teacher"].x = encode_teachers(sample["teachers"])
    data["user"].x = encode_users(sample["users"])
    data["comment"].x = encode_comments(sample["comments"])
    data["reply"].x = encode_replies(sample["replies"])
    data["exercise"].x = encode_exercises(sample["exercises"])
    data["video"].x = encode_videos(sample["videos"])

    # Xây dựng các cạnh dựa trên mối quan hệ tham chiếu của bộ dữ liệu MOOCCubeX
    if (edge := course_field_edges(sample["fields"])).size(0) == 2:
        data["course", "edge", "field"].edge_index = edge
    if (edge := course_resource_edges(sample["resources"])).size(0) == 2:
        data["course", "edge", "resource"].edge_index = edge
    if (edge := course_teacher_edges(sample["teachers"])).size(0) == 2:
        data["course", "edge", "teacher"].edge_index = edge
    if (edge := course_school_edges(sample["course"], sample["schools"])).size(0) == 2:
        data["course", "edge", "school"].edge_index = edge
    if (edge := course_user_edges(sample["users"])).size(0) == 2:
        data["course", "edge", "user"].edge_index = edge
    if (edge := course_comment_edges(sample["comments"])).size(0) == 2:
        data["course", "edge", "comment"].edge_index = edge
    if (edge := comment_reply_edges(sample["comments"], sample["replies"])).size(0) == 2:
        data["comment", "edge", "reply"].edge_index = edge
    if (edge := user_comment_edges(sample["users"], sample["comments"])).size(0) == 2:
        data["user", "edge", "comment"].edge_index = edge
    if (edge := user_reply_edges(sample["users"], sample["replies"])).size(0) == 2:
        data["user", "edge", "reply"].edge_index = edge
    if (edge := school_user_edges(sample["schools"], sample["users"])).size(0) == 2:
        data["school", "edge", "user"].edge_index = edge
    if (edge := school_teacher_edges(sample["schools"], sample["teachers"])).size(0) == 2:
        data["school", "edge", "teacher"].edge_index = edge
    if (edge := resource_exercise_edges(sample["resources"], sample["exercises"])).size(0) == 2:
        data["resource", "edge", "exercise"].edge_index = edge
    if (edge := resource_video_edges(sample["resources"], sample["videos"])).size(0) == 2:
        data["resource", "edge", "video"].edge_index = edge

    data = T.ToUndirected()(data)
    return data

# %%
# Test data của torch_geometric
data = to_hetero_data(sample)
data
# Out:
# /home/ptdat/Desktop/graph/utils/edge.py:44: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3683.)
#   return torch.tensor(edges).T.long()
# HeteroData(
#   course={ x=[1, 2048] },
#   field={ x=[1, 1024] },
#   resource={ x=[140, 1024] },
#   school={ x=[422, 2048] },
#   teacher={ x=[2, 2048] },
#   user={ x=[41, 3] },
#   comment={ x=[0, 1024] },
#   reply={ x=[0, 1024] },
#   exercise={ x=[0, 3072] },
#   video={ x=[40, 2048] },
#   (course, edge, field)={ edge_index=[2, 1] },
#   (course, edge, resource)={ edge_index=[2, 140] },
#   (course, edge, teacher)={ edge_index=[2, 2] },
#   (course, edge, school)={ edge_index=[2, 1] },
#   (course, edge, user)={ edge_index=[2, 41] },
#   (course, edge, comment)={ edge_index=[2, 0] },
#   (school, edge, user)={ edge_index=[2, 22] },
#   (school, edge, teacher)={ edge_index=[2, 2] },
#   (resource, edge, video)={ edge_index=[2, 40] },
#   (field, rev_edge, course)={ edge_index=[2, 1] },
#   (resource, rev_edge, course)={ edge_index=[2, 140] },
#   (teacher, rev_edge, course)={ edge_index=[2, 2] },
#   (school, rev_edge, course)={ edge_index=[2, 1] },
#   (user, rev_edge, course)={ edge_index=[2, 41] },
#   (comment, rev_edge, course)={ edge_index=[2, 0] },
#   (user, rev_edge, school)={ edge_index=[2, 22] },
#   (teacher, rev_edge, school)={ edge_index=[2, 2] },
#   (video, rev_edge, resource)={ edge_index=[2, 40] }
# )

# %% [markdown]
# Lặp qua từng `course_id`, và lưu lại đồ thị của course đó.

# %%
from tqdm import tqdm
import joblib
import os

os.makedirs("samples", exist_ok=True)
for row in tqdm(courses.itertuples(), desc="Storing samples to disk", total=courses.shape[0]):
    course_id = row.id
    label = row.course_classification
    if os.path.isfile(f"samples/{course_id}.pkl"):
        continue

    try:
        sample = query(course_id, db)
        data = to_hetero_data(sample)
        obj = {
            "_id": course_id,
            "data": data,
            "label": label
        }
        joblib.dump(obj, f"samples/{course_id}.pkl")
    except Exception as e:
        print(f"Error processing course {course_id}: {e}")
        continue
# Out:
# Storing samples to disk:   0%|          | 1/3781 [01:22<86:09:34, 82.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 14
#      12 try:
#      13     sample = query(course_id, db)
# ---> 14     data = to_hetero_data(sample)
#      15     obj = {
#      16         "_id": course_id,
#      17         "data": data,
#      18         "label": label
#      19     }
#      20     joblib.dump(obj, f"samples/{course_id}.pkl")
#
# Cell In[7], line 11, in to_hetero_data(sample)
#       9 data["field"].x = encode_fields(sample["fields"])
#      10 data["resource"].x = encode_resources(sample["resources"])
# ---> 11 data["school"].x = encode_schools(sample["schools"])
#      12 data["teacher"].x = encode_teachers(sample["teachers"])
#      13 data["user"].x = encode_users(sample["users"])
#
# File ~/Desktop/graph/utils/encode.py:81, in encode_schools(schools)
#      78     abouts.append(school["about"])
#      79     mottos.append(school["motto"])
# ---> 81 about_embed = forward_llm(llm, abouts)
#      82 motto_embed = forward_llm(llm, mottos)
#      83 representation = torch.cat([about_embed, motto_embed], dim=-1)
#
# File ~/Desktop/venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Desktop/graph/utils/encode.py:32, in forward_llm(llm, text, batch_size, device)
#      28 for batch in chunks(text, batch_size):
#      29     model_inputs = tokenizer(
#      30         batch, return_tensors="pt", padding=True, truncation=True
#      31     ).to(device)
# ---> 32     batch_output = model.roberta(**model_inputs).last_hidden_state[:, 0, :].cpu()
#      33     output.append(batch_output)
#      34 return torch.cat(output, dim=0)
#
# KeyboardInterrupt:

# %%
joblib.load("/home/ptdat/Desktop/graph/samples/C_655852.pkl")
# Out:
# {'_id': 'C_655852',
#  'data': HeteroData(
#    course={ x=[1, 2048] },
#    field={ x=[0, 1024] },
#    resource={ x=[162, 1024] },
#    school={ x=[422, 2048] },
#    teacher={ x=[1, 2048] },
#    user={ x=[2, 3] },
#    comment={ x=[0, 1024] },
#    reply={ x=[0, 1024] },
#    exercise={ x=[472, 3072] },
#    video={ x=[30, 2048] },
#    (course, edge, field)={ edge_index=[2, 0] },
#    (course, edge, resource)={ edge_index=[2, 162] },
#    (course, edge, teacher)={ edge_index=[2, 1] },
#    (course, edge, school)={ edge_index=[2, 1] },
#    (course, edge, user)={ edge_index=[2, 2] },
#    (course, edge, comment)={ edge_index=[2, 0] },
#    (school, edge, user)={ edge_index=[2, 1] },
#    (school, edge, teacher)={ edge_index=[2, 1] },
#    (resource, edge, exercise)={ edge_index=[2, 472] },
#    (resource, edge, video)={ edge_index=[2, 30] },
#    (field, rev_edge, course)={ edge_index=[2, 0] },
#    (resource, rev_edge, course)={ edge_index=[2, 162] },
#    (teacher, rev_edge, course)={ edge_index=[2, 1] },
#    (school, rev_edge, course)={ edge_index=[2, 1] },
#    (user, rev_edge, course)={ edge_index=[2, 2] },
#    (comment, rev_edge, course)={ edge_index=[2, 0] },
#    (user, rev_edge, school)={ edge_index=[2, 1] },
#    (teacher, rev_edge, school)={ edge_index=[2, 1] },
#    (exercise, rev_edge, resource)={ edge_index=[2, 472] },
#    (video, rev_edge, resource)={ edge_index=[2, 30] }
#  ),
#  'label': 'normal'}
